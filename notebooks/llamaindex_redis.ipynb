# %% [markdown]
# Setup a Redis vector store that works with LlamaIndex for the FAQ, amenities, and services info.
#
# I provide metadata information because LlamaIndex can have the LLM filter by it.

# %% [markdown]
# Load environment variables from .env file

# %%
import os

from dotenv import load_dotenv

load_dotenv("../.env")
# Out:
# True

# %% [markdown]
# For info on what's happening in the background

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %% [markdown]
# Setup the embedding model

# %%
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: BAAI/bge-small-en-v1.5
# Load pretrained SentenceTransformer: BAAI/bge-small-en-v1.5
# DEBUG:httpcore.connection:connect_tcp.started host='huggingface.co' port=443 local_address=None timeout=10 socket_options=None
# connect_tcp.started host='huggingface.co' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001DA2141CEC0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001DA2141CEC0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001DA2113F570> server_hostname='huggingface.co' timeout=10
# start_tls.started ssl_context=<ssl.SSLContext object at 0x000001DA2113F570> server_hostname='huggingface.co' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001DA212F3390>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001DA212F3390>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'250'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:57 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2Fmodules.json=&etag=%22952a9b81c0bfd99800fabf352f69c7ccd46c5e43%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d81-66d53a510d906ae421814893;7437726e-6f94-487d-9dec-03383e5dee2c'), (b'RateLimit', b'"resolvers";r=19999;t=255'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'modules.json; filename="modules.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"952a9b81c0bfd99800fabf352f69c7ccd46c5e43"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'xi4vP9ixCyzfQZz5EBo6XsdYM0XjHVUgpAYIhNL4g86x4K_oiT5cFA==')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'250'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:57 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2Fmodules.json=&etag=%22952a9b81c0bfd99800fabf352f69c7ccd46c5e43%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d81-66d53a510d906ae421814893;7437726e-6f94-487d-9dec-03383e5dee2c'), (b'RateLimit', b'"resolvers";r=19999;t=255'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'modules.json; filename="modules.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"952a9b81c0bfd99800fabf352f69c7ccd46c5e43"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'xi4vP9ixCyzfQZz5EBo6XsdYM0XjHVUgpAYIhNL4g86x4K_oiT5cFA==')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'349'), (b'Connection', b'keep-alive'), (b'Date', b'Fri, 28 Nov 2025 03:29:38 GMT'), (b'ETag', b'"952a9b81c0bfd99800fabf352f69c7ccd46c5e43"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69291722-0d9ccd68586bd7a70f9f535e;80cc8846-d73c-4bd3-84bd-ef817563b2f9'), (b'RateLimit', b'"resolvers";r=19998;t=34'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'modules.json; filename="modules.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'dF0pWcY3Yq4VIJ-eDqZKdJSSQ3922N4PRSRquoDWEif_xR0VRC2p8w=='), (b'Age', b'2307679')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'349'), (b'Connection', b'keep-alive'), (b'Date', b'Fri, 28 Nov 2025 03:29:38 GMT'), (b'ETag', b'"952a9b81c0bfd99800fabf352f69c7ccd46c5e43"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69291722-0d9ccd68586bd7a70f9f535e;80cc8846-d73c-4bd3-84bd-ef817563b2f9'), (b'RateLimit', b'"resolvers";r=19998;t=34'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'modules.json; filename="modules.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'dF0pWcY3Yq4VIJ-eDqZKdJSSQ3922N4PRSRquoDWEif_xR0VRC2p8w=='), (b'Age', b'2307679')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json "HTTP/1.1 200 OK"
# HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'292'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:57 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2Fconfig_sentence_transformers.json=&etag=%22dcb0c0d97d09b930d13600b1a773ddb27e441aab%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d81-74fd31b7201225587f21a240;768f9c75-c7e6-4f0d-ba59-b341d31aaf42'), (b'RateLimit', b'"resolvers";r=19998;t=255'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config_sentence_transformers.json; filename="config_sentence_transformers.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"dcb0c0d97d09b930d13600b1a773ddb27e441aab"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'rV9u--qXp_HGCk5s3Ehtw4QmBS7vBsN1zrL0WsW0kPTgz6mioPFrZA==')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'292'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:57 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2Fconfig_sentence_transformers.json=&etag=%22dcb0c0d97d09b930d13600b1a773ddb27e441aab%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d81-74fd31b7201225587f21a240;768f9c75-c7e6-4f0d-ba59-b341d31aaf42'), (b'RateLimit', b'"resolvers";r=19998;t=255'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config_sentence_transformers.json; filename="config_sentence_transformers.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"dcb0c0d97d09b930d13600b1a773ddb27e441aab"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'rV9u--qXp_HGCk5s3Ehtw4QmBS7vBsN1zrL0WsW0kPTgz6mioPFrZA==')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'124'), (b'Connection', b'keep-alive'), (b'Date', b'Fri, 28 Nov 2025 03:29:39 GMT'), (b'ETag', b'"dcb0c0d97d09b930d13600b1a773ddb27e441aab"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69291723-24ea6f320770dd602d6a4ef1;9813c62a-113f-4c52-a542-9100563a5f70'), (b'RateLimit', b'"resolvers";r=19995;t=33'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config_sentence_transformers.json; filename="config_sentence_transformers.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'juaE0s_7k86qefyqj17pv1bftsbmNnERxmRi5sGG_E1Hnx4pFskznA=='), (b'Age', b'2307678')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'124'), (b'Connection', b'keep-alive'), (b'Date', b'Fri, 28 Nov 2025 03:29:39 GMT'), (b'ETag', b'"dcb0c0d97d09b930d13600b1a773ddb27e441aab"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69291723-24ea6f320770dd602d6a4ef1;9813c62a-113f-4c52-a542-9100563a5f70'), (b'RateLimit', b'"resolvers";r=19995;t=33'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config_sentence_transformers.json; filename="config_sentence_transformers.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'juaE0s_7k86qefyqj17pv1bftsbmNnERxmRi5sGG_E1Hnx4pFskznA=='), (b'Age', b'2307678')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json "HTTP/1.1 200 OK"
# HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'292'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:57 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2Fconfig_sentence_transformers.json=&etag=%22dcb0c0d97d09b930d13600b1a773ddb27e441aab%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d81-3d6071c63b2c8c566951282c;118a6d9e-a824-4169-b37d-6d2775a5c45b'), (b'RateLimit', b'"resolvers";r=19997;t=255'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config_sentence_transformers.json; filename="config_sentence_transformers.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"dcb0c0d97d09b930d13600b1a773ddb27e441aab"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'pQnhwITeO0WXPce00fF81SvzPrNm2ibQi_VYDkIU5APLkE_0isgTWA==')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'292'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:57 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2Fconfig_sentence_transformers.json=&etag=%22dcb0c0d97d09b930d13600b1a773ddb27e441aab%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d81-3d6071c63b2c8c566951282c;118a6d9e-a824-4169-b37d-6d2775a5c45b'), (b'RateLimit', b'"resolvers";r=19997;t=255'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config_sentence_transformers.json; filename="config_sentence_transformers.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"dcb0c0d97d09b930d13600b1a773ddb27e441aab"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'pQnhwITeO0WXPce00fF81SvzPrNm2ibQi_VYDkIU5APLkE_0isgTWA==')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'124'), (b'Connection', b'keep-alive'), (b'Date', b'Fri, 28 Nov 2025 03:29:39 GMT'), (b'ETag', b'"dcb0c0d97d09b930d13600b1a773ddb27e441aab"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69291723-24ea6f320770dd602d6a4ef1;9813c62a-113f-4c52-a542-9100563a5f70'), (b'RateLimit', b'"resolvers";r=19995;t=33'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config_sentence_transformers.json; filename="config_sentence_transformers.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'M8KLETpUnFd72IRRo-w7uvsCvg-N1evHDB821r3A3Ke1RclAr_pKkA=='), (b'Age', b'2307678')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'124'), (b'Connection', b'keep-alive'), (b'Date', b'Fri, 28 Nov 2025 03:29:39 GMT'), (b'ETag', b'"dcb0c0d97d09b930d13600b1a773ddb27e441aab"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69291723-24ea6f320770dd602d6a4ef1;9813c62a-113f-4c52-a542-9100563a5f70'), (b'RateLimit', b'"resolvers";r=19995;t=33'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config_sentence_transformers.json; filename="config_sentence_transformers.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'M8KLETpUnFd72IRRo-w7uvsCvg-N1evHDB821r3A3Ke1RclAr_pKkA=='), (b'Age', b'2307678')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json "HTTP/1.1 200 OK"
# HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'244'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:57 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/README.md?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2FREADME.md=&etag=%228b8567d75ffa619486d9590cb0eb76d66ad46c49%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d81-18c2a07b11bfeb2b44f23400;745123b2-c472-49b6-9bd6-bbf9c328d580'), (b'RateLimit', b'"resolvers";r=19996;t=255'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'README.md; filename="README.md";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"8b8567d75ffa619486d9590cb0eb76d66ad46c49"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'n8f0fxUWJTJGVL9d2reau828RNggmObYy6OKqBTCFsWDYac3DI3ENQ==')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'244'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:57 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/README.md?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2FREADME.md=&etag=%228b8567d75ffa619486d9590cb0eb76d66ad46c49%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d81-18c2a07b11bfeb2b44f23400;745123b2-c472-49b6-9bd6-bbf9c328d580'), (b'RateLimit', b'"resolvers";r=19996;t=255'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'README.md; filename="README.md";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"8b8567d75ffa619486d9590cb0eb76d66ad46c49"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'n8f0fxUWJTJGVL9d2reau828RNggmObYy6OKqBTCFsWDYac3DI3ENQ==')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'94783'), (b'Connection', b'keep-alive'), (b'Date', b'Tue, 09 Dec 2025 19:44:48 GMT'), (b'ETag', b'"8b8567d75ffa619486d9590cb0eb76d66ad46c49"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69387c30-6bdb594b0f1a8f6d105a837b;24dc66bf-34b7-45bc-b2bc-d76b126f1967'), (b'RateLimit', b'"resolvers";r=19995;t=24'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'README.md; filename="README.md";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'xA3jTLJgrMzt55Z3RbTif3Un26JrAKr_Te_6PZW4VzUXlw0xkYypog=='), (b'Age', b'1298769')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'94783'), (b'Connection', b'keep-alive'), (b'Date', b'Tue, 09 Dec 2025 19:44:48 GMT'), (b'ETag', b'"8b8567d75ffa619486d9590cb0eb76d66ad46c49"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69387c30-6bdb594b0f1a8f6d105a837b;24dc66bf-34b7-45bc-b2bc-d76b126f1967'), (b'RateLimit', b'"resolvers";r=19995;t=24'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'README.md; filename="README.md";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'xA3jTLJgrMzt55Z3RbTif3Un26JrAKr_Te_6PZW4VzUXlw0xkYypog=='), (b'Age', b'1298769')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/README.md "HTTP/1.1 200 OK"
# HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/README.md "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'250'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:58 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2Fmodules.json=&etag=%22952a9b81c0bfd99800fabf352f69c7ccd46c5e43%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d82-12251b73550373a226286b10;8b18a689-4b3e-45e4-b76e-589b9c69d355'), (b'RateLimit', b'"resolvers";r=19995;t=254'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'modules.json; filename="modules.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"952a9b81c0bfd99800fabf352f69c7ccd46c5e43"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'5ZUPgUx4lEG-o8oWt4MRpG9SBOJyDBdZjfc6Ti8MGFJ3OlusHN7XkA==')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'250'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:58 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2Fmodules.json=&etag=%22952a9b81c0bfd99800fabf352f69c7ccd46c5e43%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d82-12251b73550373a226286b10;8b18a689-4b3e-45e4-b76e-589b9c69d355'), (b'RateLimit', b'"resolvers";r=19995;t=254'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'modules.json; filename="modules.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"952a9b81c0bfd99800fabf352f69c7ccd46c5e43"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'5ZUPgUx4lEG-o8oWt4MRpG9SBOJyDBdZjfc6Ti8MGFJ3OlusHN7XkA==')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'349'), (b'Connection', b'keep-alive'), (b'Date', b'Tue, 09 Dec 2025 19:44:48 GMT'), (b'ETag', b'"952a9b81c0bfd99800fabf352f69c7ccd46c5e43"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69387c30-46df017c2b8b17af56ac7793;6ae3b336-2259-4ccb-b55c-7cb6a88c3c84'), (b'RateLimit', b'"resolvers";r=19993;t=24'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'modules.json; filename="modules.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'I2d__HSOP9qXX90VXkHWVS1RB5_9xZ5Ku3lS3RROdYww6CL1IgIctw=='), (b'Age', b'1298770')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'349'), (b'Connection', b'keep-alive'), (b'Date', b'Tue, 09 Dec 2025 19:44:48 GMT'), (b'ETag', b'"952a9b81c0bfd99800fabf352f69c7ccd46c5e43"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69387c30-46df017c2b8b17af56ac7793;6ae3b336-2259-4ccb-b55c-7cb6a88c3c84'), (b'RateLimit', b'"resolvers";r=19993;t=24'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'modules.json; filename="modules.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'I2d__HSOP9qXX90VXkHWVS1RB5_9xZ5Ku3lS3RROdYww6CL1IgIctw=='), (b'Age', b'1298770')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json "HTTP/1.1 200 OK"
# HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# ...
# send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Content-Length', b'2242'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:58 GMT'), (b'ETag', b'W/"8c2-+B357tswuSDPZQJ4PcEV7JZlfTw"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d82-00abd4787b6613df1d6c333f;ba1139e6-ce82-460a-8ad0-2b24353bdc33'), (b'RateLimit', b'"api";r=2998;t=254'), (b'RateLimit-Policy', b'"fixed window";"api";q=3000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'GeJwiO55pitU2pHS4eObxCMBnTxoMmsLBhsfkfA3-VTGHsuYCv5NsA==')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Content-Length', b'2242'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:58 GMT'), (b'ETag', b'W/"8c2-+B357tswuSDPZQJ4PcEV7JZlfTw"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d82-00abd4787b6613df1d6c333f;ba1139e6-ce82-460a-8ad0-2b24353bdc33'), (b'RateLimit', b'"api";r=2998;t=254'), (b'RateLimit-Policy', b'"fixed window";"api";q=3000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'GeJwiO55pitU2pHS4eObxCMBnTxoMmsLBhsfkfA3-VTGHsuYCv5NsA==')])
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-small-en-v1.5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-small-en-v1.5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'272'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:59 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/1_Pooling%2Fconfig.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2F1_Pooling%2Fconfig.json=&etag=%221da070f0993788c8851a652170ff013aa54dd519%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d83-1cced44025bc8a4d08aee384;5c91ca5f-2ba2-421c-a784-2ed173847d94'), (b'RateLimit', b'"resolvers";r=19990;t=253'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config.json; filename="config.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"1da070f0993788c8851a652170ff013aa54dd519"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'95F9erPr3wPJoLv5-rLXx70j_e6Jrsjfvh6eb3W9LKZlHJyC13o2Gg==')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 307, b'Temporary Redirect', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'272'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:59 GMT'), (b'Location', b'/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/1_Pooling%2Fconfig.json?%2FBAAI%2Fbge-small-en-v1.5%2Fresolve%2Fmain%2F1_Pooling%2Fconfig.json=&etag=%221da070f0993788c8851a652170ff013aa54dd519%22'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d83-1cced44025bc8a4d08aee384;5c91ca5f-2ba2-421c-a784-2ed173847d94'), (b'RateLimit', b'"resolvers";r=19990;t=253'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin, Accept'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'HIT'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config.json; filename="config.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'X-Linked-ETag', b'"1da070f0993788c8851a652170ff013aa54dd519"'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'95F9erPr3wPJoLv5-rLXx70j_e6Jrsjfvh6eb3W9LKZlHJyC13o2Gg==')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'190'), (b'Connection', b'keep-alive'), (b'Date', b'Fri, 28 Nov 2025 03:29:45 GMT'), (b'ETag', b'"1da070f0993788c8851a652170ff013aa54dd519"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69291729-08cbe294131f6ea16ef7e7f4;f3231d7b-f3e6-4273-b035-99a42eac7c51'), (b'RateLimit', b'"resolvers";r=19964;t=27'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config.json; filename="config.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'6IIFXBUm2yHLH1d_Ch4TEfunClsF2rGtmJy2yuDPe601WRP1kxyIcw=='), (b'Age', b'2307674')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'text/plain; charset=utf-8'), (b'Content-Length', b'190'), (b'Connection', b'keep-alive'), (b'Date', b'Fri, 28 Nov 2025 03:29:45 GMT'), (b'ETag', b'"1da070f0993788c8851a652170ff013aa54dd519"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-69291729-08cbe294131f6ea16ef7e7f4;f3231d7b-f3e6-4273-b035-99a42eac7c51'), (b'RateLimit', b'"resolvers";r=19964;t=27'), (b'RateLimit-Policy', b'"fixed window";"resolvers";q=20000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Repo-Commit', b'5c38ec7c405ec4b44b94cc5a9bb96e735b38267a'), (b'Accept-Ranges', b'bytes'), (b'X-Hub-Cache', b'MISS'), (b'Content-Disposition', b'inline; filename*=UTF-8\'\'config.json; filename="config.json";'), (b'Content-Security-Policy', b"default-src 'none'; sandbox"), (b'Vary', b'Origin'), (b'X-Cache', b'Hit from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'6IIFXBUm2yHLH1d_Ch4TEfunClsF2rGtmJy2yuDPe601WRP1kxyIcw=='), (b'Age', b'2307674')])
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Content-Length', b'149057'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:59 GMT'), (b'ETag', b'W/"24641-WsdTnegweX4QhYdjpc3lYgNgNI4"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d83-77b213484d7508472637556c;b95d25a6-f612-4dc4-80f3-8a62a2667af6'), (b'RateLimit', b'"api";r=2997;t=253'), (b'RateLimit-Policy', b'"fixed window";"api";q=3000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'yUuBPNdV4CcpSg9VsUnW0l9NBiKg8-Z0H3I5hWWIiTXhbDQPm-sbYw==')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Content-Length', b'149057'), (b'Connection', b'keep-alive'), (b'Date', b'Wed, 24 Dec 2025 20:30:59 GMT'), (b'ETag', b'W/"24641-WsdTnegweX4QhYdjpc3lYgNgNI4"'), (b'X-Powered-By', b'huggingface-moon'), (b'X-Request-Id', b'Root=1-694c4d83-77b213484d7508472637556c;b95d25a6-f612-4dc4-80f3-8a62a2667af6'), (b'RateLimit', b'"api";r=2997;t=253'), (b'RateLimit-Policy', b'"fixed window";"api";q=3000;w=300'), (b'cross-origin-opener-policy', b'same-origin'), (b'Referrer-Policy', b'strict-origin-when-cross-origin'), (b'Access-Control-Max-Age', b'86400'), (b'Access-Control-Allow-Origin', b'https://huggingface.co'), (b'Vary', b'Origin'), (b'Access-Control-Expose-Headers', b'X-Repo-Commit,X-Request-Id,X-Error-Code,X-Error-Message,X-Total-Count,ETag,Link,Accept-Ranges,Content-Range,X-Linked-Size,X-Linked-ETag,X-Xet-Hash'), (b'X-Cache', b'Miss from cloudfront'), (b'Via', b'1.1 12468094e35c8a577a333f469209441a.cloudfront.net (CloudFront)'), (b'X-Amz-Cf-Pop', b'DEN53-P4'), (b'X-Amz-Cf-Id', b'yUuBPNdV4CcpSg9VsUnW0l9NBiKg8-Z0H3I5hWWIiTXhbDQPm-sbYw==')])
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-small-en-v1.5 "HTTP/1.1 200 OK"
# HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-small-en-v1.5 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# INFO:sentence_transformers.SentenceTransformer:1 prompt is loaded, with the key: query
# 1 prompt is loaded, with the key: query

# %% [markdown]
# ### FAQ
#
# Connect to Redis Cloud

# %%
from llama_index.core import StorageContext, VectorStoreIndex
from llama_index.vector_stores.redis import RedisVectorStore
from redisvl.schema import IndexSchema

redis_conn_string = os.getenv("REDIS_URL")
schema = IndexSchema.from_dict(
    {
        "index": {"name": "FAQ", "prefix": "FAQ"},
        # customize fields that are indexed
        "fields": [
            # required fields for llamaindex
            {"type": "tag", "name": "id"},
            {"type": "tag", "name": "doc_id"},
            {"type": "text", "name": "text"},
            # custom for metadata filtering
            {"type": "tag", "name": "category"},
            # {"type": "tag", "name": "subcategory"},
            # custom vector field for bge-small-en-v1.5 embeddings
            {
                "type": "vector",
                "name": "vector",
                "attrs": {
                    "dims": 384,
                    "algorithm": "hnsw",
                    "distance_metric": "cosine",
                },
            },
        ],
    },
)
vector_store = RedisVectorStore(schema=schema, redis_url=redis_conn_string, overwrite=True)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
# Out:
# 13:07:14 redisvl.index.index INFO   Index already exists, overwriting.
# 13:07:14 redisvl.index.index INFO   Index already exists, overwriting.

# %% [markdown]
# Load the FAQ

# %%
import pandas as pd

df_faq = pd.read_pickle("../data/pandas/faq_knowledge_base.pkl")
df_faq
# Out:
#             category       subcategory  \
# faq_id
# FAQ000001    booking      reservations
# FAQ000002    booking      check-in/out
# FAQ000003    booking     modifications
# FAQ000004    booking     cancellations
# FAQ000005    booking  special requests
# FAQ000006  amenities        facilities
# FAQ000007  amenities            dining
# FAQ000008  amenities          wellness
# FAQ000009  amenities          business
# FAQ000010  amenities        recreation
# FAQ000011   services      room service
# FAQ000012   services      housekeeping
# FAQ000013   services         concierge
# FAQ000014   services    transportation
# FAQ000015   services          business
# FAQ000016   policies        pet policy
# FAQ000017   policies    smoking policy
# FAQ000018   policies    payment policy
# FAQ000019   policies  age requirements
# FAQ000020   policies    luggage policy
#
#                                               question  \
# faq_id
# FAQ000001                 How do I make a reservation?
# FAQ000002         What is the check-in/check-out time?
# FAQ000003                     Can I modify my booking?
# FAQ000004             What is the cancellation policy?
# FAQ000005  Do you offer early check-in/late check-out?
# FAQ000006                 What amenities are included?
# FAQ000007                       Is breakfast included?
# FAQ000008                Do you have a fitness center?
# FAQ000009                    Is there a swimming pool?
# FAQ000010                   Do you offer spa services?
# FAQ000011                   Is room service available?
# FAQ000012                Do you offer laundry service?
# FAQ000013                  Is there a business center?
# FAQ000014            Do you provide airport transfers?
# FAQ000015                        Is parking available?
# FAQ000016                     What is your pet policy?
# FAQ000017                   Do you have smoking rooms?
# FAQ000018         What forms of payment do you accept?
# FAQ000019          Is there a minimum age to check in?
# FAQ000020         What is your luggage storage policy?
#
#                                                       answer  \
# faq_id
# FAQ000001  You can make a reservation through our website...
# FAQ000002  Check-in time is 3:00 PM and check-out time is...
# FAQ000003  Yes, you can modify your booking through our w...
# FAQ000004  Free cancellation is available up to 48 hours ...
# FAQ000005  Subject to availability, early check-in and la...
# FAQ000006  Our hotel offers complimentary Wi-Fi, fitness ...
# FAQ000007  Yes, breakfast is included with most room rate...
# FAQ000008  Yes, our fitness center is open 24/7 and featu...
# FAQ000009  Yes, we have both indoor and outdoor pools ope...
# FAQ000010  Our full-service spa offers massages, facials,...
# FAQ000011  Room service is available 24/7 with a full men...
# FAQ000012  Yes, same-day laundry and dry-cleaning service...
# FAQ000013  Our business center is open 24/7 and offers co...
# FAQ000014  Yes, we offer airport shuttle service for a fe...
# FAQ000015  We offer both self-parking and valet parking s...
# FAQ000016  We welcome pets under 25 pounds for an additio...
# FAQ000017  All our rooms are non-smoking. Smoking is only...
# FAQ000018  We accept all major credit cards, debit cards,...
# FAQ000019  Guests must be 18 or older to check in. Valid ...
# FAQ000020  Complimentary luggage storage is available bef...
#
#                                                 keywords last_updated  \
# faq_id
# FAQ000001            book, reserve, reservation, booking   2024-03-09
# FAQ000002        check in, check out, arrival, departure   2024-10-15
# FAQ000003                   change, modify, update, edit   2024-12-05
# FAQ000004                   cancel, refund, cancellation   2024-05-20
# FAQ000005  early check-in, late check-out, extended stay   2024-12-18
# FAQ000006                amenities, facilities, services   2024-10-24
# FAQ000007                  breakfast, dining, restaurant   2024-01-10
# FAQ000008                         fitness, gym, exercise   2024-10-05
# FAQ000009                     pool, swimming, recreation   2024-10-15
# FAQ000010                      spa, wellness, treatments   2024-01-07
# FAQ000011                     room service, dining, food   2024-04-05
# FAQ000012                laundry, cleaning, housekeeping   2024-09-16
# FAQ000013                         business, work, office   2024-05-25
# FAQ000014                     airport, shuttle, transfer   2024-11-27
# FAQ000015                            parking, valet, car   2024-02-03
# FAQ000016                      pets, animals, dogs, cats   2024-07-17
# FAQ000017                  smoking, non-smoking, tobacco   2024-01-31
# FAQ000018                     payment, credit card, cash   2024-10-30
# FAQ000019                    age, check-in, requirements   2024-01-09
# FAQ000020                         luggage, storage, bags   2024-06-20
#
#            helpful_votes  views
# faq_id
# FAQ000001            957   3813
# FAQ000002            967   2793
# FAQ000003            443   1929
# FAQ000004            611   1300
# FAQ000005            239   3954
# FAQ000006            855   1860
# FAQ000007            365   1943
# FAQ000008            988   1471
# FAQ000009            400   2881
# FAQ000010            145    766
# FAQ000011            708   2133
# FAQ000012            126    249
# FAQ000013            925   1604
# FAQ000014            743   1621
# FAQ000015            721   1975
# FAQ000016            639   4327
# FAQ000017            703   2992
# FAQ000018            799   2778
# FAQ000019            662   4150
# FAQ000020            127    213

# %% [markdown]
# Prepare data for storage

# %%
from llama_index.core.schema import TextNode

def get_faq_nodes():
    nodes = []
    for id_, row in df_faq.iterrows():
        main_text = "Question:\n" + row["question"] + "\n\nAnswer:\n" + row["answer"]
        metadata = {"category": row["category"],
                    "subcategory": row["subcategory"],
                    "keywords": row["keywords"],
                    "last_updated": row["last_updated"]}
        node = TextNode(text=main_text, id_=id_, metadata=metadata)
        nodes.append(node)
    return nodes

nodes = get_faq_nodes()

# %% [markdown]
# Store in vector store

# %%
index = VectorStoreIndex(nodes=nodes, storage_context=storage_context)
# Out:
# 13:07:14 llama_index.vector_stores.redis.base INFO   Added 20 documents to index FAQ
# 13:07:14 llama_index.vector_stores.redis.base INFO   Added 20 documents to index FAQ

# %% [markdown]
# Setup and test retrieval

# %%
retriever = index.as_retriever(similarity_top_k=3)

# %%
retriever.retrieve("Is there a place to swim?")
# Out:
# 13:07:15 llama_index.vector_stores.redis.base INFO   Querying index FAQ with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:07:15 llama_index.vector_stores.redis.base INFO   Querying index FAQ with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:07:15 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['FAQ:FAQ000009', 'FAQ:FAQ000006', 'FAQ:FAQ000010']
# 13:07:15 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['FAQ:FAQ000009', 'FAQ:FAQ000006', 'FAQ:FAQ000010']
# [NodeWithScore(node=TextNode(id_='FAQ000009', embedding=None, metadata={'category': 'amenities', 'subcategory': 'business', 'keywords': 'pool, swimming, recreation', 'last_updated': '2024-10-15'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nIs there a swimming pool?\n\nAnswer:\nYes, we have both indoor and outdoor pools open from 6:00 AM to 10:00 PM.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.741773724556),
#  NodeWithScore(node=TextNode(id_='FAQ000006', embedding=None, metadata={'category': 'amenities', 'subcategory': 'facilities', 'keywords': 'amenities, facilities, services', 'last_updated': '2024-10-24'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nWhat amenities are included?\n\nAnswer:\nOur hotel offers complimentary Wi-Fi, fitness center, pool, spa, restaurant, and 24-hour room service.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.651285409927),
#  NodeWithScore(node=TextNode(id_='FAQ000010', embedding=None, metadata={'category': 'amenities', 'subcategory': 'recreation', 'keywords': 'spa, wellness, treatments', 'last_updated': '2024-01-07'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nDo you offer spa services?\n\nAnswer:\nOur full-service spa offers massages, facials, and body treatments. Advance booking is recommended.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.650461614132)]

# %% [markdown]
# Setup and auto-retriever that filters over metadata

# %%
from llama_index.core.retrievers import VectorIndexAutoRetriever
from llama_index.core.vector_stores.types import MetadataInfo, VectorStoreInfo

faq_store_info = VectorStoreInfo(
    content_info="FAQs and their answers for the hotel",
    metadata_info=[
        MetadataInfo(
            name="category",
            type="str",
            description=f"Category of the FAQ, one of {df_faq["category"].unique().tolist()}",
        ),
        # MetadataInfo(
        #     name="subcategory",
        #     type="str",
        #     description=f"Subcategory of the FAQ, one of {df_faq["subcategory"].unique().tolist()}"
        # ),
    ],
)
retriever=VectorIndexAutoRetriever(index, vector_store_info=faq_store_info)

# %% [markdown]
# The auto-retriever clearly doesn't work for the FAQs.

# %%
retriever.retrieve("Is there a place to swim?")
# Out:
# 13:07:18 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 13:07:18 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 13:07:18 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using query str: place to swim
# 13:07:18 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using query str: place to swim
# 13:07:18 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using filters: [('category', '==', 'services')]
# 13:07:18 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using filters: [('category', '==', 'services')]
# 13:07:18 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using top_k: 2
# 13:07:18 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using top_k: 2
# 13:07:18 llama_index.vector_stores.redis.base INFO   Querying index FAQ with query @category:{services}=>[KNN 2 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 2
# 13:07:18 llama_index.vector_stores.redis.base INFO   Querying index FAQ with query @category:{services}=>[KNN 2 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 2
# 13:07:18 llama_index.vector_stores.redis.base INFO   Found 2 results for query with id ['FAQ:FAQ000011', 'FAQ:FAQ000013']
# 13:07:18 llama_index.vector_stores.redis.base INFO   Found 2 results for query with id ['FAQ:FAQ000011', 'FAQ:FAQ000013']
# [NodeWithScore(node=TextNode(id_='FAQ000011', embedding=None, metadata={'category': 'services', 'subcategory': 'room service', 'keywords': 'room service, dining, food', 'last_updated': '2024-04-05'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nIs room service available?\n\nAnswer:\nRoom service is available 24/7 with a full menu during restaurant hours and a limited menu overnight.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.581247210503),
#  NodeWithScore(node=TextNode(id_='FAQ000013', embedding=None, metadata={'category': 'services', 'subcategory': 'concierge', 'keywords': 'business, work, office', 'last_updated': '2024-05-25'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nIs there a business center?\n\nAnswer:\nOur business center is open 24/7 and offers computers, printing, and meeting rooms.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.578524112701)]

# %%
retriever.retrieve("What's the policy on smoking?")
# Out:
# 13:07:20 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 13:07:20 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 13:07:20 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using query str: policy on smoking
# 13:07:20 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using query str: policy on smoking
# 13:07:20 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using filters: [('category', '==', 'policies')]
# 13:07:20 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using filters: [('category', '==', 'policies')]
# 13:07:20 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using top_k: 2
# 13:07:20 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using top_k: 2
# 13:07:20 llama_index.vector_stores.redis.base INFO   Querying index FAQ with query @category:{policies}=>[KNN 2 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 2
# 13:07:20 llama_index.vector_stores.redis.base INFO   Querying index FAQ with query @category:{policies}=>[KNN 2 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 2
# 13:07:20 llama_index.vector_stores.redis.base INFO   Found 2 results for query with id ['FAQ:FAQ000017', 'FAQ:FAQ000016']
# 13:07:20 llama_index.vector_stores.redis.base INFO   Found 2 results for query with id ['FAQ:FAQ000017', 'FAQ:FAQ000016']
# [NodeWithScore(node=TextNode(id_='FAQ000017', embedding=None, metadata={'category': 'policies', 'subcategory': 'smoking policy', 'keywords': 'smoking, non-smoking, tobacco', 'last_updated': '2024-01-31'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nDo you have smoking rooms?\n\nAnswer:\nAll our rooms are non-smoking. Smoking is only permitted in designated outdoor areas.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.786777734756),
#  NodeWithScore(node=TextNode(id_='FAQ000016', embedding=None, metadata={'category': 'policies', 'subcategory': 'pet policy', 'keywords': 'pets, animals, dogs, cats', 'last_updated': '2024-07-17'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nWhat is your pet policy?\n\nAnswer:\nWe welcome pets under 25 pounds for an additional fee. Please notify us in advance.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6674103736879999)]

# %% [markdown]
# ### Amenities

# %% [markdown]
# Connect to Redis Cloud

# %%
from llama_index.core import StorageContext, VectorStoreIndex
from llama_index.vector_stores.redis import RedisVectorStore
from redisvl.schema import IndexSchema

redis_conn_string = os.getenv("REDIS_URL")
schema = IndexSchema.from_dict(
    {
        "index": {"name": "Amenities", "prefix": "Amenities"},
        # customize fields that are indexed
        "fields": [
            # required fields for llamaindex
            {"type": "tag", "name": "id"},
            {"type": "tag", "name": "doc_id"},
            {"type": "text", "name": "text"},
            # custom fields for filtering
            {"type": "tag", "name": "category"},
            {"type": "numeric", "name": "price"},
            {"type": "numeric", "name": "duration"},
            {"type": "numeric", "name": "min_notice_hours"},
            # custom vector field for bge-small-en-v1.5 embeddings
            {
                "type": "vector",
                "name": "vector",
                "attrs": {
                    "dims": 384,
                    "algorithm": "hnsw",
                    "distance_metric": "cosine",
                },
            },
        ],
    },
)
vector_store = RedisVectorStore(schema=schema, redis_url=redis_conn_string, overwrite=True)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
# Out:
# 13:14:20 redisvl.index.index INFO   Index already exists, overwriting.
# 13:14:20 redisvl.index.index INFO   Index already exists, overwriting.

# %% [markdown]
# Add amenity information

# %%
df_amenities = pd.read_pickle("../data/pandas/amenities.pkl")
df_amenities.head()
# Out:
#                 category                        name  price  duration  \
# amenity_id
# AM000001    Spa Services             Swedish Massage    120        60
# AM000002    Spa Services         Deep Tissue Massage    140        60
# AM000003    Spa Services  Couples Massage Experience    280        90
# AM000004    Spa Services           Hot Stone Therapy    160        90
# AM000005    Spa Services     Luxury Facial Treatment    180        90
#
#                                                   description  \
# amenity_id
# AM000001    Experience pure relaxation with our Swedish Ma...
# AM000002    Indulge in our signature Deep Tissue Massage, ...
# AM000003    Indulge in our signature Couples Massage Exper...
# AM000004    Experience pure relaxation with our Hot Stone ...
# AM000005    Indulge in our signature Luxury Facial Treatme...
#
#                    availability               location  booking_required  \
# amenity_id
# AM000001                   24/7  Spa & Wellness Center              True
# AM000002             6:00-22:00  Spa & Wellness Center             False
# AM000003    By appointment only  Spa & Wellness Center             False
# AM000004             6:00-22:00              Pool Area             False
# AM000005                   24/7          Main Building             False
#
#             min_notice_hours
# amenity_id
# AM000001                   2
# AM000002                   4
# AM000003                   0
# AM000004                   1
# AM000005                  24

# %% [markdown]
# Prepare data for storage

# %%
def get_amenities_nodes():
    nodes = []
    for id_, row in df_amenities.iterrows():
        main_text = "Name:" + row["name"] + "\n\nDescription:\n" + row["description"]
        metadata = {"category": row["category"],
                    "price": row["price"],
                    "duration": row["duration"],
                    "availability": row["availability"],
                    "location": row["location"],
                    "booking_required": str(row["booking_required"]),
                    "min_notice_hours": row["min_notice_hours"]}
        node = TextNode(text=main_text, id_=id_, metadata=metadata)
        nodes.append(node)
    return nodes

nodes = get_amenities_nodes()

# %% [markdown]
# Store in vector store, setup retriever

# %%
index = VectorStoreIndex(nodes=nodes, storage_context=storage_context)
retriever = index.as_retriever(similarity_top_k=3)
# Out:
# 13:14:41 llama_index.vector_stores.redis.base INFO   Added 34 documents to index Amenities
# 13:14:41 llama_index.vector_stores.redis.base INFO   Added 34 documents to index Amenities

# %%
retriever.retrieve("Can I get a massage?")
# Out:
# 13:07:21 llama_index.vector_stores.redis.base INFO   Querying index Amenities with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:07:21 llama_index.vector_stores.redis.base INFO   Querying index Amenities with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:07:21 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['Amenities:AM000003', 'Amenities:AM000002', 'Amenities:AM000001']
# 13:07:21 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['Amenities:AM000003', 'Amenities:AM000002', 'Amenities:AM000001']
# [NodeWithScore(node=TextNode(id_='AM000003', embedding=None, metadata={'category': 'Spa Services', 'price': 280, 'duration': 90, 'availability': 'By appointment only', 'location': 'Spa & Wellness Center', 'booking_required': 'False', 'min_notice_hours': 0}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Name:Couples Massage Experience\n\nDescription:\nIndulge in our signature Couples Massage Experience, where 90 minutes of expert care will melt away stress and tension. This treatment features therapeutic-grade materials and customized therapeutic approaches to provide rejuvenated and restored.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6567953825),
#  NodeWithScore(node=TextNode(id_='AM000002', embedding=None, metadata={'category': 'Spa Services', 'price': 140, 'duration': 60, 'availability': '6:00-22:00', 'location': 'Spa & Wellness Center', 'booking_required': 'False', 'min_notice_hours': 4}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Name:Deep Tissue Massage\n\nDescription:\nIndulge in our signature Deep Tissue Massage, where 60 minutes of expert care will melt away stress and tension. This treatment features natural skincare products and customized therapeutic approaches to provide rejuvenated and restored.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.653777182102),
#  NodeWithScore(node=TextNode(id_='AM000001', embedding=None, metadata={'category': 'Spa Services', 'price': 120, 'duration': 60, 'availability': '24/7', 'location': 'Spa & Wellness Center', 'booking_required': 'True', 'min_notice_hours': 2}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Name:Swedish Massage\n\nDescription:\nExperience pure relaxation with our Swedish Massage, a 60-minute treatment designed to melt away stress and tension. Our certified therapists use premium natural skincare products to precise pressure point therapy, leaving you feeling renewed and revitalized.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.648089170456)]

# %% [markdown]
# Setup and auto-retriever that filters over metadata

# %%
from llama_index.core.retrievers import VectorIndexAutoRetriever
from llama_index.core.vector_stores.types import MetadataInfo, VectorStoreInfo

amenities_store_info = VectorStoreInfo(
    content_info="Information about hotel amenities (services)",
    metadata_info=[
        MetadataInfo(
            name="category",
            type="string",
            description=f"Category of the amenity, one of {df_amenities["category"].unique().tolist()}",
        ),
        MetadataInfo(
            name="price",
            type="integer",
            description="The cost of the amenity in dollars.",
        ),
        MetadataInfo(
            name="duration",
            type="integer",
            description="The duration of the amenity in minutes. Do not use quotes. Output as a raw integer.",
        ),
        MetadataInfo(
            name="min_notice_hours",
            type="integer",
            description="How far in advance the request for the amenity needs to be made in hours.",
        ),
    ],
)
retriever=VectorIndexAutoRetriever(index, vector_store_info=amenities_store_info, similarity_top_k=3)

# %%
retriever.retrieve("I would like an hour long massage")
# Out:
# 13:07:22 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 13:07:22 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 13:07:22 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using query str: hour long massage
# 13:07:22 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using query str: hour long massage
# 13:07:22 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using filters: [('duration', '==', '60'), ('category', '==', 'Spa Services')]
# 13:07:22 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using filters: [('duration', '==', '60'), ('category', '==', 'Spa Services')]
# 13:07:22 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using top_k: 3
# 13:07:22 llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever INFO   Using top_k: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 retriever.retrieve("I would like an hour long massage")
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\core\base\base_retriever.py:210, in BaseRetriever.retrieve(self, str_or_query_bundle)
#     205 with self.callback_manager.as_trace("query"):
#     206     with self.callback_manager.event(
#     207         CBEventType.RETRIEVE,
#     208         payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     209     ) as retrieve_event:
# --> 210         nodes = self._retrieve(query_bundle)
#     211         nodes = self._handle_recursive_retrieval(query_bundle, nodes)
#     212         retrieve_event.on_end(
#     213             payload={EventPayload.NODES: nodes},
#     214         )
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\core\base\base_auto_retriever.py:37, in BaseAutoRetriever._retrieve(self, query_bundle)
#      35 retrieval_spec = self.generate_retrieval_spec(query_bundle)
#      36 retriever, new_query_bundle = self._build_retriever_from_spec(retrieval_spec)
# ---> 37 return retriever.retrieve(new_query_bundle)
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\core\base\base_retriever.py:210, in BaseRetriever.retrieve(self, str_or_query_bundle)
#     205 with self.callback_manager.as_trace("query"):
#     206     with self.callback_manager.event(
#     207         CBEventType.RETRIEVE,
#     208         payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     209     ) as retrieve_event:
# --> 210         nodes = self._retrieve(query_bundle)
#     211         nodes = self._handle_recursive_retrieval(query_bundle, nodes)
#     212         retrieve_event.on_end(
#     213             payload={EventPayload.NODES: nodes},
#     214         )
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\core\indices\vector_store\retrievers\retriever.py:104, in VectorIndexRetriever._retrieve(self, query_bundle)
#      98     if query_bundle.embedding is None and len(query_bundle.embedding_strs) > 0:
#      99         query_bundle.embedding = (
#     100             self._embed_model.get_agg_embedding_from_queries(
#     101                 query_bundle.embedding_strs
#     102             )
#     103         )
# --> 104 return self._get_nodes_with_embeddings(query_bundle)
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\core\indices\vector_store\retrievers\retriever.py:220, in VectorIndexRetriever._get_nodes_with_embeddings(self, query_bundle_with_embeddings)
#     216 def _get_nodes_with_embeddings(
#     217     self, query_bundle_with_embeddings: QueryBundle
#     218 ) -> List[NodeWithScore]:
#     219     query = self._build_vector_store_query(query_bundle_with_embeddings)
# --> 220     query_result = self._vector_store.query(query, **self._kwargs)
#     222     nodes_to_fetch = self._determine_nodes_to_fetch(query_result)
#     223     if nodes_to_fetch:
#     224         # Fetch any missing nodes from the docstore and insert them into the query result
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\vector_stores\redis\base.py:667, in RedisVectorStore.query(self, query, **kwargs)
#     664 if not query.query_embedding:
#     665     raise ValueError("Query embedding is required for querying.")
# --> 667 redis_query = self._to_redis_query(query)
#     668 logger.info(f"Querying index {self._index.name} with query {redis_query!s}")
#     670 try:
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\vector_stores\redis\base.py:603, in RedisVectorStore._to_redis_query(self, query)
#     601     filter_expression = self._to_redis_filters(query.filters)
#     602 else:
# --> 603     filter_expression = self._create_redis_filter_expression(query.filters)
#     604 return_fields = self._return_fields.copy()
#     605 return VectorQuery(
#     606     vector=query.query_embedding,
#     607     vector_field_name=VECTOR_FIELD_NAME,
#    (...)    610     return_fields=return_fields,
#     611 )
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\vector_stores\redis\base.py:552, in RedisVectorStore._create_redis_filter_expression(self, metadata_filters)
#     550         continue
#     551     # Extract redis filter
# --> 552     redis_filter = self._to_redis_filter(field, filter)
#     554 # Combine with conditional
#     555 if metadata_filters.condition == "and":
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\vector_stores\redis\base.py:521, in RedisVectorStore._to_redis_filter(field, filter)
#     519 # Create field instance and apply the operator function
#     520 field_instance = field_info["class"](field.name)
# --> 521 return field_info["operators"][filter.operator](field_instance, filter.value)
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\llama_index\vector_stores\redis\utils.py:19, in <lambda>(f, v)
#       1 from redisvl.query.filter import Tag, Num, Text
#       4 # Global constant defining field specifications
#       5 REDIS_LLAMA_FIELD_SPEC = {
#       6     "tag": {
#       7         "class": Tag,
#       8         "operators": {
#       9             "==": lambda f, v: f == v,
#      10             "!=": lambda f, v: f != v,
#      11             "in": lambda f, v: f == v,
#      12             "nin": lambda f, v: f != v,
#      13             "contains": lambda f, v: f == v,
#      14         },
#      15     },
#      16     "numeric": {
#      17         "class": Num,
#      18         "operators": {
# ---> 19             "==": lambda f, v: f == v,
#      20             "!=": lambda f, v: f != v,
#      21             ">": lambda f, v: f > v,
#      22             "<": lambda f, v: f < v,
#      23             ">=": lambda f, v: f >= v,
#      24             "<=": lambda f, v: f <= v,
#      25         },
#      26     },
#      27     "text": {
#      28         "class": Text,
#      29         "operators": {
#      30             "==": lambda f, v: f == v,
#      31             "!=": lambda f, v: f != v,
#      32             "text_match": lambda f, v: f % v,
#      33         },
#      34     },
#      35 }
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\redisvl\query\filter.py:293, in Num.__eq__(self, other)
#     281 def __eq__(self, other: int) -> "FilterExpression":
#     282     """Create a Numeric equality filter expression.
#     283
#     284     Args:
#    (...)    291
#     292     """
# --> 293     self._set_value(other, self.SUPPORTED_VAL_TYPES, FilterOperator.EQ)
#     294     return FilterExpression(str(self))
#
# File d:\pypoetry\Cache\virtualenvs\blue-horizon-ai-concierge-cYemaw-w-py3.13\Lib\site-packages\redisvl\query\filter.py:52, in FilterField._set_value(self, val, val_type, operator)
#      50 # check that the value is of the proper type
#      51 if not isinstance(val, val_type):
# ---> 52     raise TypeError(
#      53         f"Right side argument passed to operator {self.OPERATORS[operator]} "
#      54         f"with left side "
#      55         f"argument {self.__class__.__name__} must be of type {val_type}"
#      56     )
#      57 self._value = val
#      58 self._operator = operator
#
# TypeError: Right side argument passed to operator == with left side argument Num must be of type (<class 'int'>, <class 'float'>, <class 'NoneType'>)

# %% [markdown]
# ### Services
#
# I would like to combine this with amenities as the dataset columns are almost identical, but this set doesn't have availability information. In practice, I would just ask for this information, but I can't do that here, so I'm keeping them separate.

# %% [markdown]
# Connect to Redis Cloud

# %%
from llama_index.core import StorageContext, VectorStoreIndex
from llama_index.vector_stores.redis import RedisVectorStore
from redisvl.schema import IndexSchema

redis_conn_string = os.getenv("REDIS_URL")
schema = IndexSchema.from_dict(
    {
        "index": {"name": "Services", "prefix": "Services"},
        # customize fields that are indexed
        "fields": [
            # required fields for llamaindex
            {"type": "tag", "name": "id"},
            {"type": "tag", "name": "doc_id"},
            {"type": "text", "name": "text"},
            # custom vector field for bge-small-en-v1.5 embeddings
            {
                "type": "vector",
                "name": "vector",
                "attrs": {
                    "dims": 384,
                    "algorithm": "hnsw",
                    "distance_metric": "cosine",
                },
            },
        ],
    },
)
vector_store = RedisVectorStore(schema=schema, redis_url=redis_conn_string, overwrite=True)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
# Out:
# 13:07:28 redisvl.index.index INFO   Index already exists, overwriting.
# 13:07:28 redisvl.index.index INFO   Index already exists, overwriting.

# %% [markdown]
# Add services information

# %%
df_services = pd.read_pickle("../data/pandas/services.pkl")
df_services.head()
# Out:
#                  service_type                        name  \
# service_id
# SV000001        Spa Treatment     Spa Treatment - 120 min
# SV000002        Spa Treatment      Spa Treatment - 60 min
# SV000003        Spa Treatment     Spa Treatment - 120 min
# SV000004        Spa Treatment      Spa Treatment - 90 min
# SV000005    Personal Training  Personal Training - 60 min
#
#                                                   description  \
# service_id
# SV000001    Swedish massage for 120 minutes using Modern t...
# SV000002    Luxurious 60-minute Deep Tissue treatment feat...
# SV000003    Premium Deep Tissue experience for 120 minutes...
# SV000004    Luxurious 90-minute Hot Stone treatment featur...
# SV000005    Custom 60-minute HIIT workout emphasizing Core...
#
#             duration_minutes   price      department  booking_required  \
# service_id
# SV000001                 120  264.98  Spa & Wellness              True
# SV000002                  60  232.03  Spa & Wellness              True
# SV000003                 120  251.99  Spa & Wellness              True
# SV000004                  90  157.55  Spa & Wellness              True
# SV000005                  60  133.13  Fitness Center              True
#
#             min_notice_hours
# service_id
# SV000001                   4
# SV000002                   4
# SV000003                  24
# SV000004                   1
# SV000005                   4

# %%
def get_services_nodes():
    nodes = []
    for id_, row in df_services.iterrows():
        main_text = "Name:" + row["name"] + "\n\nDescription:\n" + row["description"]
        metadata = {"service_type": row["service_type"],
                    "duration_minutes": row["duration_minutes"],
                    "price": row["price"],
                    "department": row["department"],
                    "booking_required": str(row["booking_required"]),
                    "min_notice_hours": row["min_notice_hours"]}
        node = TextNode(text=main_text, id_=id_, metadata=metadata)
        nodes.append(node)
    return nodes

nodes = get_services_nodes()

# %%
index = VectorStoreIndex(nodes=nodes, storage_context=storage_context)
retriever = index.as_retriever(similarity_top_k=3)
# Out:
# 13:07:35 llama_index.vector_stores.redis.base INFO   Added 25 documents to index Services
# 13:07:35 llama_index.vector_stores.redis.base INFO   Added 25 documents to index Services

# %%
retriever.retrieve("I want to do some pilates.")
# Out:
# 13:07:36 llama_index.vector_stores.redis.base INFO   Querying index Services with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:07:36 llama_index.vector_stores.redis.base INFO   Querying index Services with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:07:36 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['Services:SV000024', 'Services:SV000008', 'Services:SV000007']
# 13:07:36 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['Services:SV000024', 'Services:SV000008', 'Services:SV000007']
# [NodeWithScore(node=TextNode(id_='SV000024', embedding=None, metadata={'service_type': 'Group Fitness Class', 'duration_minutes': 45, 'price': 30.93, 'department': 'Fitness Center', 'booking_required': 'True', 'min_notice_hours': 1}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Name:Group Fitness Class - 45 min\n\nDescription:\nEngaging 45-minute Pilates class emphasizing Strength. Group Motivation.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.663864791393),
#  NodeWithScore(node=TextNode(id_='SV000008', embedding=None, metadata={'service_type': 'Personal Training', 'duration_minutes': 60, 'price': 143.7, 'department': 'Fitness Center', 'booking_required': 'True', 'min_notice_hours': 2}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Name:Personal Training - 60 min\n\nDescription:\nCustom 60-minute Strength Training workout emphasizing Full Body. Better Flexibility.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.573877573013),
#  NodeWithScore(node=TextNode(id_='SV000007', embedding=None, metadata={'service_type': 'Personal Training', 'duration_minutes': 60, 'price': 82.2, 'department': 'Fitness Center', 'booking_required': 'True', 'min_notice_hours': 24}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Name:Personal Training - 60 min\n\nDescription:\nPersonalized Functional Fitness training for 60 minutes targeting Lower Body. Enhanced Endurance.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.570849835873)]

# %% [markdown]
# Since I can't get the auto-retriever to work with Redis, I'm just going to stick the FAQ, services, and amenities in the same index. If I have time, I will look at using a different vector database that works with the auto-retriever.

# %%
redis_conn_string = os.getenv("REDIS_URL")
schema = IndexSchema.from_dict(
    {
        "index": {"name": "blue_horizon", "prefix": "blue_horizon"},
        # customize fields that are indexed
        "fields": [
            # required fields for llamaindex
            {"type": "tag", "name": "id"},
            {"type": "tag", "name": "doc_id"},
            {"type": "text", "name": "text"},
            # custom vector field for bge-small-en-v1.5 embeddings
            {
                "type": "vector",
                "name": "vector",
                "attrs": {
                    "dims": 384,
                    "algorithm": "hnsw",
                    "distance_metric": "cosine",
                },
            },
        ],
    },
)
vector_store = RedisVectorStore(schema=schema, redis_url=redis_conn_string, overwrite=True)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
# Out:
# 13:21:39 redisvl.index.index INFO   Index already exists, overwriting.
# 13:21:39 redisvl.index.index INFO   Index already exists, overwriting.

# %%
faq_nodes = get_faq_nodes()
amenities_nodes = get_amenities_nodes()
services_nodes = get_services_nodes()

# %%
index = VectorStoreIndex(nodes=faq_nodes, storage_context=storage_context)
index.insert_nodes(amenities_nodes)
index.insert_nodes(services_nodes)
# Out:
# 13:22:27 llama_index.vector_stores.redis.base INFO   Added 20 documents to index blue_horizon
# 13:22:27 llama_index.vector_stores.redis.base INFO   Added 20 documents to index blue_horizon
# 13:22:27 llama_index.vector_stores.redis.base INFO   Added 34 documents to index blue_horizon
# 13:22:27 llama_index.vector_stores.redis.base INFO   Added 34 documents to index blue_horizon
# 13:22:28 llama_index.vector_stores.redis.base INFO   Added 25 documents to index blue_horizon
# 13:22:28 llama_index.vector_stores.redis.base INFO   Added 25 documents to index blue_horizon

# %%
retriever = index.as_retriever(similarity_top_k=3)
retriever.retrieve("Can I go for a swim?")
# Out:
# 13:23:27 llama_index.vector_stores.redis.base INFO   Querying index blue_horizon with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:23:27 llama_index.vector_stores.redis.base INFO   Querying index blue_horizon with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:23:27 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['blue_horizon:FAQ000009', 'blue_horizon:FAQ000010', 'blue_horizon:FAQ000005']
# 13:23:27 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['blue_horizon:FAQ000009', 'blue_horizon:FAQ000010', 'blue_horizon:FAQ000005']
# [NodeWithScore(node=TextNode(id_='FAQ000009', embedding=None, metadata={'category': 'amenities', 'subcategory': 'business', 'keywords': 'pool, swimming, recreation', 'last_updated': '2024-10-15'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nIs there a swimming pool?\n\nAnswer:\nYes, we have both indoor and outdoor pools open from 6:00 AM to 10:00 PM.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.686123907566),
#  NodeWithScore(node=TextNode(id_='FAQ000010', embedding=None, metadata={'category': 'amenities', 'subcategory': 'recreation', 'keywords': 'spa, wellness, treatments', 'last_updated': '2024-01-07'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nDo you offer spa services?\n\nAnswer:\nOur full-service spa offers massages, facials, and body treatments. Advance booking is recommended.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.644719541073),
#  NodeWithScore(node=TextNode(id_='FAQ000005', embedding=None, metadata={'category': 'booking', 'subcategory': 'special requests', 'keywords': 'early check-in, late check-out, extended stay', 'last_updated': '2024-12-18'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nDo you offer early check-in/late check-out?\n\nAnswer:\nSubject to availability, early check-in and late check-out can be arranged for an additional fee.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.629732251167)]

# %%
retriever.retrieve("Can I get a massage?")
# Out:
# 13:23:58 llama_index.vector_stores.redis.base INFO   Querying index blue_horizon with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:23:58 llama_index.vector_stores.redis.base INFO   Querying index blue_horizon with query *=>[KNN 3 @vector $vector AS vector_distance] RETURN 5 id doc_id text _node_content vector_distance SORTBY vector_distance ASC DIALECT 2 LIMIT 0 3
# 13:23:58 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['blue_horizon:FAQ000010', 'blue_horizon:AM000003', 'blue_horizon:AM000002']
# 13:23:58 llama_index.vector_stores.redis.base INFO   Found 3 results for query with id ['blue_horizon:FAQ000010', 'blue_horizon:AM000003', 'blue_horizon:AM000002']
# [NodeWithScore(node=TextNode(id_='FAQ000010', embedding=None, metadata={'category': 'amenities', 'subcategory': 'recreation', 'keywords': 'spa, wellness, treatments', 'last_updated': '2024-01-07'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Question:\nDo you offer spa services?\n\nAnswer:\nOur full-service spa offers massages, facials, and body treatments. Advance booking is recommended.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7244102358819999),
#  NodeWithScore(node=TextNode(id_='AM000003', embedding=None, metadata={'category': 'Spa Services', 'price': 280, 'duration': 90, 'availability': 'By appointment only', 'location': 'Spa & Wellness Center', 'booking_required': 'False', 'min_notice_hours': 0}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Name:Couples Massage Experience\n\nDescription:\nIndulge in our signature Couples Massage Experience, where 90 minutes of expert care will melt away stress and tension. This treatment features therapeutic-grade materials and customized therapeutic approaches to provide rejuvenated and restored.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6567953825),
#  NodeWithScore(node=TextNode(id_='AM000002', embedding=None, metadata={'category': 'Spa Services', 'price': 140, 'duration': 60, 'availability': '6:00-22:00', 'location': 'Spa & Wellness Center', 'booking_required': 'False', 'min_notice_hours': 4}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Name:Deep Tissue Massage\n\nDescription:\nIndulge in our signature Deep Tissue Massage, where 60 minutes of expert care will melt away stress and tension. This treatment features natural skincare products and customized therapeutic approaches to provide rejuvenated and restored.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.653777182102)]
