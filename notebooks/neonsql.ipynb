# %% [markdown]
# ## Neon SQL
#
# I use Neon SQL (a cloud service) to store the rooms information. This notebook tests loading the data and retrieving it.

# %%
# ruff: noqa: T201, S101, S301

import os

import psycopg
from dotenv import load_dotenv
from psycopg import sql

# %%
# Load environment variables from .env file
load_dotenv()
neon_conn_string = os.environ["PGSQL_ROOT_DB_URL"]

# %%
import pandas as pd

# %% [markdown]
# ## Rooms table
#
# First we need the rooms table as its primary key is referenced by the room_availability table.

# %%
df_rooms = pd.read_pickle("../data/pandas/rooms.pkl")
df_rooms
# Out:
#       room_id  room_number  floor                type  square_feet  \
# 0    RM000001          101      1            Standard          410
# 1    RM000002          102      1            Standard          361
# 2    RM000003          103      1            Standard          431
# 3    RM000004          104      1            Standard          391
# 4    RM000005          105      1            Standard          373
# ..        ...          ...    ...                 ...          ...
# 595  RM000596         2026     20  Presidential Suite         2369
# 596  RM000597         2027     20  Presidential Suite         2020
# 597  RM000598         2028     20  Presidential Suite         1883
# 598  RM000599         2029     20  Presidential Suite         1643
# 599  RM000600         2030     20  Presidential Suite         1671
#
#                                        basic_amenities  \
# 0    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 1    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 2    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 3    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 4    [Air Conditioning, Smart TV, Premium Coffee Ma...
# ..                                                 ...
# 595  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 596  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 597  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 598  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 599  [Air Conditioning, Multiple 75" Smart TVs, Pro...
#
#                                   additional_amenities  max_occupancy  \
# 0                                                   []              2
# 1                           [Evening Turndown Service]              2
# 2                                                   []              2
# 3                           [Evening Turndown Service]              2
# 4                           [Evening Turndown Service]              2
# ..                                                 ...            ...
# 595  [Private Terrace, Private Pool, Luxury Car Ser...              6
# 596  [Private Terrace, Private Gym Equipment, Luxur...              6
# 597  [Private Terrace, Sauna, Private Butler Servic...              6
# 598  [Private Terrace, Private Pool, Private Chef A...              6
# 599  [Private Terrace, Sauna, Private Butler Servic...              6
#
#                       bed_type                    view_type  accessibility  \
# 0                        Queen                  [City View]          False
# 1                        Queen              [Standard View]          False
# 2                 Double Queen             [Courtyard View]          False
# 3                        Queen  [City View, Courtyard View]           True
# 4                 Double Queen  [City View, Courtyard View]           True
# ..                         ...                          ...            ...
# 595  King + Multiple Sofa Beds              [Standard View]          False
# 596  King + Multiple Sofa Beds              [Standard View]          False
# 597  King + Multiple Sofa Beds              [Standard View]          False
# 598  King + Multiple Sofa Beds              [Standard View]          False
# 599  King + Multiple Sofa Beds       [Panoramic Ocean View]          False
#
#           status last_renovation  base_rate  max_rate
# 0      Available      2022-10-25        350       500
# 1      Available      2023-03-01        350       500
# 2      Available      2022-08-10        350       500
# 3       Occupied      2023-09-06        350       500
# 4       Occupied      2024-04-13        350       500
# ..           ...             ...        ...       ...
# 595  Maintenance      2024-10-01       3500      5000
# 596  Maintenance      2024-04-17       3500      5000
# 597     Occupied      2022-03-09       3500      5000
# 598  Maintenance      2023-07-24       3500      5000
# 599  Maintenance      2022-10-06       3500      5000
#
# [600 rows x 15 columns]

# %%
print(df_rooms.iloc[121])
# Out:
# room_id                                                          RM000122
# room_number                                                           502
# floor                                                                   5
# type                                                               Deluxe
# square_feet                                                           460
# basic_amenities         [Air Conditioning, 55" Smart TV, Nespresso Mac...
# additional_amenities                                        [Soaking Tub]
# max_occupancy                                                           3
# bed_type                                                     Double Queen
# view_type                                         [Pool View, Ocean View]
# accessibility                                                       False
# status                                                           Occupied
# last_renovation                                                2024-11-25
# base_rate                                                             500
# max_rate                                                              750
# Name: 121, dtype: object

# %% [markdown]
# Convert the room_id to an int for more efficient use in SQL.

# %%
df_rooms["room_id"] = df_rooms["room_id"].apply(lambda x: int(x[2:]))
df_rooms
# Out:
#      room_id  room_number  floor                type  square_feet  \
# 0          1          101      1            Standard          410
# 1          2          102      1            Standard          361
# 2          3          103      1            Standard          431
# 3          4          104      1            Standard          391
# 4          5          105      1            Standard          373
# ..       ...          ...    ...                 ...          ...
# 595      596         2026     20  Presidential Suite         2369
# 596      597         2027     20  Presidential Suite         2020
# 597      598         2028     20  Presidential Suite         1883
# 598      599         2029     20  Presidential Suite         1643
# 599      600         2030     20  Presidential Suite         1671
#
#                                        basic_amenities  \
# 0    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 1    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 2    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 3    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 4    [Air Conditioning, Smart TV, Premium Coffee Ma...
# ..                                                 ...
# 595  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 596  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 597  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 598  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 599  [Air Conditioning, Multiple 75" Smart TVs, Pro...
#
#                                   additional_amenities  max_occupancy  \
# 0                                                   []              2
# 1                           [Evening Turndown Service]              2
# 2                                                   []              2
# 3                           [Evening Turndown Service]              2
# 4                           [Evening Turndown Service]              2
# ..                                                 ...            ...
# 595  [Private Terrace, Private Pool, Luxury Car Ser...              6
# 596  [Private Terrace, Private Gym Equipment, Luxur...              6
# 597  [Private Terrace, Sauna, Private Butler Servic...              6
# 598  [Private Terrace, Private Pool, Private Chef A...              6
# 599  [Private Terrace, Sauna, Private Butler Servic...              6
#
#                       bed_type                    view_type  accessibility  \
# 0                        Queen                  [City View]          False
# 1                        Queen              [Standard View]          False
# 2                 Double Queen             [Courtyard View]          False
# 3                        Queen  [City View, Courtyard View]           True
# 4                 Double Queen  [City View, Courtyard View]           True
# ..                         ...                          ...            ...
# 595  King + Multiple Sofa Beds              [Standard View]          False
# 596  King + Multiple Sofa Beds              [Standard View]          False
# 597  King + Multiple Sofa Beds              [Standard View]          False
# 598  King + Multiple Sofa Beds              [Standard View]          False
# 599  King + Multiple Sofa Beds       [Panoramic Ocean View]          False
#
#           status last_renovation  base_rate  max_rate
# 0      Available      2022-10-25        350       500
# 1      Available      2023-03-01        350       500
# 2      Available      2022-08-10        350       500
# 3       Occupied      2023-09-06        350       500
# 4       Occupied      2024-04-13        350       500
# ..           ...             ...        ...       ...
# 595  Maintenance      2024-10-01       3500      5000
# 596  Maintenance      2024-04-17       3500      5000
# 597     Occupied      2022-03-09       3500      5000
# 598  Maintenance      2023-07-24       3500      5000
# 599  Maintenance      2022-10-06       3500      5000
#
# [600 rows x 15 columns]

# %% [markdown]
# Get room types to create enum

# %%
room_type = df_rooms["type"].unique().tolist()
room_type_str = "('" + "', '".join(room_type) + "')"
room_type_str
# Out:
# "('Standard', 'Deluxe', 'Suite', 'Presidential Suite')"

# %% [markdown]
# Get room bed types to create enum

# %%
room_bed_type = df_rooms["bed_type"].unique().tolist()
room_bed_type_str = "('" + "', '".join(room_bed_type) + "')"
room_bed_type_str
# Out:
# "('Queen', 'Double Queen', 'King', 'Double King', 'King + Sofa Bed', 'King + Multiple Sofa Beds')"

# %% [markdown]
# Get statuses to create enum

# %%
room_status_type = df_rooms["status"].unique().tolist()
room_status_type_str = "('" + "', '".join(room_status_type) + "')"
room_status_type_str
# Out:
# "('Available', 'Occupied', 'Maintenance')"

# %% [markdown]
# Check that room_ids are sequential and start with 1

# %%
assert sum(df_rooms["room_id"].iloc[1:].to_numpy() -
           df_rooms["room_id"].iloc[:-1].to_numpy()) == df_rooms.shape[0]-1
assert df_rooms["room_id"].iloc[0] == 1

# %% [markdown]
# For some reason only the room_type enum needs special treatment (otherwise there's a cache error). I use more complicated ones for the bed_type and status columns, but they don't have a problem.

# %%
from enum import Enum


class RoomType(Enum):
    """Room type stored in the SQL `room_type` enum column."""

    Standard = "Standard"
    Deluxe = "Deluxe"
    Suite = "Suite"
    Presidential_Suite = "Presidential Suite"

enum_room_type_mapping = {
    "Standard": RoomType.Standard,
    "Deluxe": RoomType.Deluxe,
    "Suite": RoomType.Suite,
    "Presidential Suite": RoomType.Presidential_Suite,
}

sql_room_type_mapping = [
        (RoomType.Standard, "Standard"),
        (RoomType.Deluxe, "Deluxe"),
        (RoomType.Suite, "Suite"),
        (RoomType.Presidential_Suite, "Presidential Suite"),
]

# %%
df_rooms["type"] = df_rooms["type"].apply(lambda x: enum_room_type_mapping[x])
df_rooms
# Out:
#      room_id  room_number  floor                         type  square_feet  \
# 0          1          101      1            RoomType.Standard          410
# 1          2          102      1            RoomType.Standard          361
# 2          3          103      1            RoomType.Standard          431
# 3          4          104      1            RoomType.Standard          391
# 4          5          105      1            RoomType.Standard          373
# ..       ...          ...    ...                          ...          ...
# 595      596         2026     20  RoomType.Presidential_Suite         2369
# 596      597         2027     20  RoomType.Presidential_Suite         2020
# 597      598         2028     20  RoomType.Presidential_Suite         1883
# 598      599         2029     20  RoomType.Presidential_Suite         1643
# 599      600         2030     20  RoomType.Presidential_Suite         1671
#
#                                        basic_amenities  \
# 0    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 1    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 2    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 3    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 4    [Air Conditioning, Smart TV, Premium Coffee Ma...
# ..                                                 ...
# 595  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 596  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 597  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 598  [Air Conditioning, Multiple 75" Smart TVs, Pro...
# 599  [Air Conditioning, Multiple 75" Smart TVs, Pro...
#
#                                   additional_amenities  max_occupancy  \
# 0                                                   []              2
# 1                           [Evening Turndown Service]              2
# 2                                                   []              2
# 3                           [Evening Turndown Service]              2
# 4                           [Evening Turndown Service]              2
# ..                                                 ...            ...
# 595  [Private Terrace, Private Pool, Luxury Car Ser...              6
# 596  [Private Terrace, Private Gym Equipment, Luxur...              6
# 597  [Private Terrace, Sauna, Private Butler Servic...              6
# 598  [Private Terrace, Private Pool, Private Chef A...              6
# 599  [Private Terrace, Sauna, Private Butler Servic...              6
#
#                       bed_type                    view_type  accessibility  \
# 0                        Queen                  [City View]          False
# 1                        Queen              [Standard View]          False
# 2                 Double Queen             [Courtyard View]          False
# 3                        Queen  [City View, Courtyard View]           True
# 4                 Double Queen  [City View, Courtyard View]           True
# ..                         ...                          ...            ...
# 595  King + Multiple Sofa Beds              [Standard View]          False
# 596  King + Multiple Sofa Beds              [Standard View]          False
# 597  King + Multiple Sofa Beds              [Standard View]          False
# 598  King + Multiple Sofa Beds              [Standard View]          False
# 599  King + Multiple Sofa Beds       [Panoramic Ocean View]          False
#
#           status last_renovation  base_rate  max_rate
# 0      Available      2022-10-25        350       500
# 1      Available      2023-03-01        350       500
# 2      Available      2022-08-10        350       500
# 3       Occupied      2023-09-06        350       500
# 4       Occupied      2024-04-13        350       500
# ..           ...             ...        ...       ...
# 595  Maintenance      2024-10-01       3500      5000
# 596  Maintenance      2024-04-17       3500      5000
# 597     Occupied      2022-03-09       3500      5000
# 598  Maintenance      2023-07-24       3500      5000
# 599  Maintenance      2022-10-06       3500      5000
#
# [600 rows x 15 columns]

# %% [markdown]
# Add table to Neon

# %%
from psycopg.types.enum import EnumInfo, register_enum

with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # drop existing stuff (if exists)
        cur.execute("DROP TABLE IF EXISTS rooms CASCADE;")
        cur.execute("DROP TYPE IF EXISTS room_type CASCADE;")
        cur.execute("DROP TYPE IF EXISTS room_bed_type CASCADE;")
        cur.execute("DROP TYPE IF EXISTS room_status_type CASCADE;")

        # Define enums for type, bed_type, and status
        cur.execute(
            sql.SQL("CREATE TYPE room_type AS ENUM ({values});").format(
                values=sql.SQL(", ").join(sql.Literal(v) for v in room_type),
            ),
        )
        cur.execute(
            sql.SQL("CREATE TYPE room_bed_type AS ENUM ({values});").format(
                values=sql.SQL(", ").join(sql.Literal(v) for v in room_bed_type),
            ),
        )
        cur.execute(
            sql.SQL("CREATE TYPE room_status_type AS ENUM ({values});").format(
                values=sql.SQL(", ").join(sql.Literal(v) for v in room_status_type),
            ),
        )

        # Create a new table
        cur.execute("""
            CREATE TABLE rooms (
                room_id INT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
                room_number INT NOT NULL,
                floor INT NOT NULL,
                type room_type,
                square_feet INT,
                basic_amenities TEXT[],  -- Array data type for basic amenities
                additional_amenities TEXT[], -- Array data type for additional amenities
                max_occupancy INT,
                bed_type room_bed_type,
                view_type TEXT[],  -- Array data type for view type
                accessibility BOOLEAN,
                status room_status_type,
                last_renovation DATE,
                base_rate NUMERIC(10, 2),
                max_rate NUMERIC(10, 2)
            );
        """)
        print("Finished creating table.")

    # room_type enum special treatment
    info = EnumInfo.fetch(neon_conn, "room_type")
    if info is None:
        msg = "room_type enum was not found in the database after creation."
        raise RuntimeError(msg)
    register_enum(info, context=neon_conn, enum=RoomType, mapping=sql_room_type_mapping)

    with neon_conn.cursor() as cur:
        # Insert room availability data
        cur.executemany(
            "INSERT INTO rooms VALUES (" + "%s, "*(len(df_rooms.columns)-1) + "%s);",
            df_rooms.to_numpy().tolist(),
        )
        print("Inserted data.")
# Out:
# Connection established
# Finished creating table.
# Inserted data.

# %% [markdown]
# ## Room Availability table
#
# Now add the room_availability table

# %%
df_room_availability = pd.read_pickle("../data/pandas/room_availability.pkl")
df_room_availability
# Out:
#          room_id  room_number        date     status   price  max_occupancy
# 0       RM000001          101  2025-01-04     Booked    None              2
# 1       RM000001          101  2025-01-05     Booked    None              2
# 2       RM000001          101  2025-01-06     Booked    None              2
# 3       RM000001          101  2025-01-07     Booked    None              2
# 4       RM000001          101  2025-01-08     Booked    None              2
# ...          ...          ...         ...        ...     ...            ...
# 218995  RM000600         2030  2025-12-30     Booked    None              6
# 218996  RM000600         2030  2025-12-31     Booked    None              6
# 218997  RM000600         2030  2026-01-01     Booked    None              6
# 218998  RM000600         2030  2026-01-02  Available  4617.6              6
# 218999  RM000600         2030  2026-01-03  Available  5000.0              6
#
# [219000 rows x 6 columns]

# %% [markdown]
# Convert room_id to int for more efficient use in SQL and because used that way in rooms table.

# %%
df_room_availability["room_id"] = df_room_availability["room_id"].apply(
    lambda x: int(x[2:]),
)
df_room_availability
# Out:
#         room_id  room_number        date     status   price  max_occupancy
# 0             1          101  2025-01-04     Booked    None              2
# 1             1          101  2025-01-05     Booked    None              2
# 2             1          101  2025-01-06     Booked    None              2
# 3             1          101  2025-01-07     Booked    None              2
# 4             1          101  2025-01-08     Booked    None              2
# ...         ...          ...         ...        ...     ...            ...
# 218995      600         2030  2025-12-30     Booked    None              6
# 218996      600         2030  2025-12-31     Booked    None              6
# 218997      600         2030  2026-01-01     Booked    None              6
# 218998      600         2030  2026-01-02  Available  4617.6              6
# 218999      600         2030  2026-01-03  Available  5000.0              6
#
# [219000 rows x 6 columns]

# %%
df_room_availability.to_numpy().tolist()
# Out:
# [[1, 101, '2025-01-04', 'Booked', None, 2],
#  [3, 103, '2025-09-01', 'Booked', None, 2],
#  [3, 103, '2025-09-02', 'Booked', None, 2],
#  [3, 103, '2025-09-03', 'Booked', None, 2],
#  [3, 103, '2025-09-04', 'Booked', None, 2],
#  [3, 103, '2025-09-05', 'Booked', None, 2],
#  [3, 103, '2025-09-06', 'Booked', None, 2],
#  [3, 103, '2025-09-07', 'Booked', None, 2],
#  [3, 103, '2025-09-08', 'Booked', None, 2],
#  [3, 103, '2025-09-09', 'Booked', None, 2],
#  [3, 103, '2025-09-10', 'Booked', None, 2],
#  [3, 103, '2025-09-11', 'Booked', None, 2],
#  [3, 103, '2025-09-12', 'Booked', None, 2],
#  [3, 103, '2025-09-13', 'Booked', None, 2],
#  [3, 103, '2025-09-14', 'Booked', None, 2],
#  [3, 103, '2025-09-15', 'Booked', None, 2],
#  [3, 103, '2025-09-16', 'Booked', None, 2],
#  [3, 103, '2025-09-17', 'Booked', None, 2],
#  [3, 103, '2025-09-18', 'Booked', None, 2],
#  [3, 103, '2025-09-19', 'Booked', None, 2],
#  [3, 103, '2025-09-20', 'Booked', None, 2],
#  [3, 103, '2025-09-21', 'Booked', None, 2],
#  [3, 103, '2025-09-22', 'Booked', None, 2],
#  [3, 103, '2025-09-23', 'Booked', None, 2],
#  [3, 103, '2025-09-24', 'Booked', None, 2],
#  [3, 103, '2025-09-25', 'Booked', None, 2],
#  [3, 103, '2025-09-26', 'Booked', None, 2],
#  [3, 103, '2025-09-27', 'Available', 446.83, 2],
#  [3, 103, '2025-09-28', 'Available', 433.15, 2],
#  [3, 103, '2025-09-29', 'Booked', None, 2],
#  [3, 103, '2025-09-30', 'Booked', None, 2],
#  ...]

# %% [markdown]
# Create the status enum string

# %%
availability_status_type = df_room_availability["status"].unique().tolist()
availability_status_type_str = "('" + "', '".join(availability_status_type) + "')"
availability_status_type_str
# Out:
# "('Booked', 'Available', 'Maintenance')"

# %% [markdown]
# This enum also has a problem with psycopg confusing it with the status enum for the rooms table.

# %%
from enum import Enum


class AvailabilityStatusType(Enum):
    """Status stored in the SQL `availability_status_type` enum column."""

    Booked = "Booked"
    Available = "Available"
    Maintenance = "Maintenance"

enum_availability_status_type_mapping = {
    "Booked": AvailabilityStatusType.Booked,
    "Available": AvailabilityStatusType.Available,
    "Maintenance": AvailabilityStatusType.Maintenance,
}

# %%
df_room_availability["status"] = df_room_availability["status"].apply(
    lambda x: enum_availability_status_type_mapping[x],
)
df_room_availability
# Out:
#         room_id  room_number        date                            status  \
# 0             1          101  2025-01-04     AvailabilityStatusType.Booked
# 1             1          101  2025-01-05     AvailabilityStatusType.Booked
# 2             1          101  2025-01-06     AvailabilityStatusType.Booked
# 3             1          101  2025-01-07     AvailabilityStatusType.Booked
# 4             1          101  2025-01-08     AvailabilityStatusType.Booked
# ...         ...          ...         ...                               ...
# 218995      600         2030  2025-12-30     AvailabilityStatusType.Booked
# 218996      600         2030  2025-12-31     AvailabilityStatusType.Booked
# 218997      600         2030  2026-01-01     AvailabilityStatusType.Booked
# 218998      600         2030  2026-01-02  AvailabilityStatusType.Available
# 218999      600         2030  2026-01-03  AvailabilityStatusType.Available
#
#          price  max_occupancy
# 0         None              2
# 1         None              2
# 2         None              2
# 3         None              2
# 4         None              2
# ...        ...            ...
# 218995    None              6
# 218996    None              6
# 218997    None              6
# 218998  4617.6              6
# 218999  5000.0              6
#
# [219000 rows x 6 columns]

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("DROP TABLE IF EXISTS room_availability;")
        cur.execute("DROP TYPE IF EXISTS availability_status_type CASCADE;")
        print("Finished dropping table and enum (if they existed).")

        cur.execute(
            sql.SQL("CREATE TYPE availability_status_type AS ENUM ({values});").format(
                values=sql.SQL(", ").join(
                    sql.Literal(v) for v in availability_status_type
                ),
            ),
        )
        # Create a new table
        cur.execute("""
            CREATE TABLE room_availability (
                id INT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
                room_id INT NOT NULL,
                room_number INT NOT NULL,
                date DATE NOT NULL,
                status availability_status_type,
                price NUMERIC(8,2),
                max_occupancy INT,
                FOREIGN KEY (room_id) REFERENCES rooms(room_id),
                CONSTRAINT room_availability_room_id_date_uniq UNIQUE (room_id, date)
            );
        """)
        print("Finished creating table.")

    # availability_status_type enum special treatment
    info = EnumInfo.fetch(neon_conn, "availability_status_type")
    if info is None:
        msg = "availability_status_type enum was not found in the database."
        raise RuntimeError(msg)
    register_enum(info, context=neon_conn, enum=AvailabilityStatusType)

    with neon_conn.cursor() as cur:
        # Insert room availability data
        cur.executemany(
            "INSERT INTO room_availability (room_id, room_number, date, status, "
            "price, max_occupancy) VALUES (%s, %s, %s, %s, %s, %s);",
            df_room_availability.to_numpy().tolist(),
        )
        print("Inserted data.")
# Out:
# Connection established
# Finished dropping table and enum (if they existed).
# Finished creating table.
# Inserted data.

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("SELECT COUNT(*) FROM room_availability")
        print(cur.fetchall())
# Out:
# Connection established
# [(219000,)]

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("""SELECT DISTINCT element FROM (
                SELECT unnest(basic_amenities) AS element
                FROM rooms
                UNION ALL
                SELECT unnest(additional_amenities) AS element
                FROM rooms);""")
        print(cur.fetchall())
# Out:
# Connection established
# [('Executive Office',), ('High-Speed WiFi',), ('Welcome Amenity',), ('Private Chef Available',), ('Private Terrace',), ('Guest Bathroom',), ('Steam Room',), ('Living Room',), ('Luxury Welcome Amenity',), ('Bang & Olufsen Sound System',), ('Ultra-High-Speed WiFi',), ('Steam Shower',), ('Multiple 75" Smart TVs',), ('Sauna',), ('Soaking Tub',), ('Balcony',), ('Multiple Bathrooms',), ('Dining Area',), ('Dedicated Concierge',), ('Designer Slippers',), ('Butler Service',), ('Formal Dining Room',), ('Private Bar',), ('Lounge Access',), ('Mini Fridge',), ('Frette Bathrobes',), ('Full Kitchen',), ('Nespresso Machine',), ('Premium Coffee Maker',), ('Wine Fridge',), ('Premium Bathrobes',), ('Kitchenette',), ('Private Gym Equipment',), ('Bathrobes',), ("Butler's Pantry",), ('Full-Size Refrigerator',), ('55" Smart TV',), ('Bluetooth Speaker',), ('Professional Coffee Bar',), ('Air Conditioning',), ('Grand Piano',), ('Work Desk',), ('Private Pool',), ('In-Room Safe',), ('Smart TV',), ('Living Room Area',), ('Personalized Stationery',), ('Hair Dryer',), ('Walk-in Closet',), ('Bose Sound System',), ('Jacuzzi Tub',), ('65" Smart TV',), ('Slippers',), ('Luxury Car Service',), ('Evening Turndown Service',), ('Executive Work Desk',), ('Microwave',), ('Wraparound Balcony',), ('Private Butler Service',), ('Executive Lounge Access',), ('Fresh Flowers Daily',)]

# %% [markdown]
# ## Customers Table

# %%
df_customers = pd.read_pickle("../data/pandas/customers.pkl")
df_customers
# Out:
#             first_name  last_name                              email  \
# customer_id
# 1               Robert      Smith       robert.smith@wyatt-huynh.com
# 2              Tiffany     Garner           tiffany.garner@smith.com
# 3             Jennifer     Miller      jennifer.miller@mccormick.com
# 4                Frank    Roberts           frank.roberts@davis.info
# 5             Patricia       Choi            patricia.choi@holt.info
# ...                ...        ...                                ...
# 49996            Stacy   Harrison            stacy.harrison@snow.com
# 49997           Cheryl   Santiago  cheryl.santiago@stone-jimenez.com
# 49998          Kaitlyn  Davenport  kaitlyn.davenport@hunt-austin.com
# 49999            Grant   Mcintosh          grant.mcintosh@howard.com
# 50000          Gregory      Duran   gregory.duran@anderson-smith.net
#
#                               phone  \
# customer_id
# 1                  001-625-164-8298
# 2            001-924-161-9263x89503
# 3                      817.900.7596
# 4                     (914)861-7623
# 5             001-399-328-3594x2880
# ...                             ...
# 49996            451-368-9921x96006
# 49997         +1-580-041-8918x34434
# 49998             (742)524-4647x339
# 49999            902.465.0973x96638
# 50000                 (581)310-4189
#
#                                                        address  \
# customer_id
# 1                698 Eddie Stravenue, East Marymouth, NH 45002
# 2            82496 Bob Expressway Suite 023, Amberburgh, MD...
# 3                             PSC 8351, Box 8217, APO AE 44482
# 4                             PSC 2055, Box 2622, APO AP 89621
# 5            58891 Eric Station Apt. 475, Parkerview, WA 65054
# ...                                                        ...
# 49996           126 Thomas Unions, North Selenahaven, SD 49492
# 49997              067 Thomas Roads, Port Stevenside, MO 47990
# 49998            6226 David Extensions, Espinozafurt, ND 24552
# 49999                    042 Jacob Glen, Port Brandy, OH 74179
# 50000                         PSC 6134, Box 9063, APO AA 18178
#
#                                                    preferences  \
# customer_id
# 1            ["Turndown service", "Gluten-free options", "S...
# 2                                 ["King bed", "Kosher meals"]
# 3            ["Extra towels", "Late check-out", "Halal meal...
# 4            ["Pet-friendly", "Anniversary celebration", "S...
# 5            ["Turndown service", "Laundry service", "Valet...
# ...                                                        ...
# 49996        ["Birthday celebration", "Concierge service", ...
# 49997        ["Extra towels", "Extra pillows", "Business tr...
# 49998        ["Birthday celebration", "Dairy-free options",...
# 49999        ["Honeymoon package", "Garden view", "Twin beds"]
# 50000        ["No housekeeping", "Valet parking", "Fitness ...
#
#                             nationality          language loyalty_tier
# customer_id
# 1                              Anguilla           Quechua         Gold
# 2                             Australia  Bihari languages     Titanium
# 3                              Djibouti           Guarani       Bronze
# 4                             Swaziland             Rundi       Bronze
# 5                               Lesotho           Bashkir       Bronze
# ...                                 ...               ...          ...
# 49996        Slovakia (Slovak Republic)         Ukrainian       Bronze
# 49997                      Turkmenistan           Panjabi       Bronze
# 49998                           Belarus              Afar     Platinum
# 49999         Bouvet Island (Bouvetoya)          Kashmiri       Bronze
# 50000                        Montenegro          Albanian     Titanium
#
# [50000 rows x 9 columns]

# %% [markdown]
# I'm going to make customer choice a dropdown list, so restrict it to 25.

# %%
df_customers = df_customers[:25][["first_name", "last_name"]]
df_customers = df_customers.reset_index()

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("DROP TABLE IF EXISTS customers CASCADE;")
        print("Finished dropping table if it existed.")
        # Create a new table
        cur.execute("""
            CREATE TABLE customers (
                customer_id INT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
                first_name VARCHAR(32) NOT NULL,
                last_name VARCHAR(32) NOT NULL
            );
        """)
        print("Finished creating table.")

        # Insert customer data
        cur.executemany(
            "INSERT INTO customers (customer_id, first_name, last_name) "
            "VALUES (%s, %s, %s);",
            df_customers.to_numpy().tolist(),
        )
        print("Inserted data.")
# Out:
# Connection established
# Finished dropping table if it existed.
# Finished creating table.
# Inserted data.

# %% [markdown]
# ## Booking tables
#
# Only create the tables, don't put anything in them. There are a bunch of pre-existing bookings, but I'll leave them out. The main issue is that if a user cancels one of the pre-existing bookings, that room is then listed as "available" without a rate.
#
# I use two tables so that a single booking can cover multiple rooms. There's a `bookings` table with the corresponding guest id, then the `booking_rooms` table with a row for each room booked.

# %% [markdown]
# First the `bookings` table

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("DROP TABLE IF EXISTS bookings CASCADE;")
        cur.execute("DROP TYPE IF EXISTS booking_status CASCADE;")
        print("Finished dropping table if it existed.")
        # Create the enum
        cur.execute("""
            CREATE TYPE booking_status AS ENUM (
                'confirmed', 'checked_in', 'checked_out', 'cancelled'
                );
            """)
        # Create a new table
        cur.execute("""
            CREATE TABLE bookings (
                booking_id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
                customer_id INT NOT NULL
                    REFERENCES customers(customer_id) ON DELETE RESTRICT,
                status booking_status NOT NULL DEFAULT 'confirmed',
                booked_at TIMESTAMPTZ NOT NULL DEFAULT now(),
                cancelled_at TIMESTAMPTZ,
                confirmation_number VARCHAR(16) UNIQUE,
                CONSTRAINT cancel_coherent
                    CHECK ((status = 'cancelled') = (cancelled_at IS NOT NULL))
            );
        """)
        print("Finished creating table.")
# Out:
# Connection established
# Finished dropping table if it existed.
# Finished creating table.

# %% [markdown]
# Then the `booking_rooms` table

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("DROP TABLE IF EXISTS booking_rooms;")
        print("Finished dropping table if it existed.")
        # Create a new table
        cur.execute("""
            CREATE TABLE booking_rooms (
                booking_room_id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
                booking_id BIGINT NOT NULL
                    REFERENCES bookings(booking_id) ON DELETE RESTRICT,
                room_id INT NOT NULL REFERENCES rooms(room_id),
                check_in DATE NOT NULL,
                check_out DATE NOT NULL,
                total_amount NUMERIC(10,2) NOT NULL,
                CHECK (check_out > check_in)
            );
        """)
        print("Finished creating table.")
# Out:
# Connection established
# Finished dropping table if it existed.
# Finished creating table.

# %% [markdown]
# ### Run Some Tests

# %%
from openai import OpenAI
from openai.types.responses import Response


class NL2SQLAgent:
    """Agent that translates natural-language questions into SQL queries.

    Uses an LLM to draft a PostgreSQL query for the `rooms` and
    `room_availability` tables, given the enums, amenities, and view types
    currently stored in the database.
    """

    def __init__(self, db_conn: psycopg.Connection, llm_conn: OpenAI) -> None:
        """Initialize the agent and cache the schema metadata it needs.

        Args:
            db_conn: Open connection to the Neon PostgreSQL database.
            llm_conn: OpenAI client used to generate SQL from natural language.

        """
        self.db = db_conn
        self.llm = llm_conn
        self._get_enums()
        self._get_amenities()
        self._get_view_types()

    def _get_enums(self) -> None:
        """Fetch and cache the SQL enum ranges used by the rooms tables."""
        with psycopg.connect(neon_conn_string) as neon_conn, neon_conn.cursor() as cur:
            cur.execute("SELECT enum_range(NULL::room_type);")
            self.room_type_enum = cur.fetchall()[0][0]
            cur.execute("SELECT enum_range(NULL::room_bed_type);")
            self.room_bed_type_enum = cur.fetchall()[0][0]
            cur.execute("SELECT enum_range(NULL::room_status_type);")
            self.room_status_type_enum = cur.fetchall()[0][0]
            cur.execute("SELECT enum_range(NULL::availability_status_type);")
            self.availability_status_type_enum = cur.fetchall()[0][0]

    def _get_amenities(self) -> None:
        """Fetch and cache the distinct basic and additional room amenities."""
        with psycopg.connect(neon_conn_string) as neon_conn, neon_conn.cursor() as cur:
            cur.execute("SELECT DISTINCT unnest(basic_amenities) FROM rooms;")
            self.basic_amenities = cur.fetchall()
            cur.execute("SELECT DISTINCT unnest(additional_amenities) FROM rooms;")
            self.additional_amenities = cur.fetchall()

    def _get_view_types(self) -> None:
        """Fetch and cache the distinct room view types."""
        with psycopg.connect(neon_conn_string) as neon_conn, neon_conn.cursor() as cur:
            cur.execute("SELECT DISTINCT unnest(view_type) FROM rooms;")
            self.view_types = cur.fetchall()

    def handle_nl_query(self, query: str) -> Response:
        """Translate a natural-language question into a SQL query.

        Args:
            query: The user's natural-language question about hotel rooms
                or their availability.

        Returns:
            The OpenAI response whose `output_text` holds the generated
            SQL query.

        """
        instructions = f"""
            You are a SQL query writer. Given the user's input, write a query that, when
            passed to a PostgreSQL database, will gather the data necessary to answer
            the user's query. Write a raw query. Do not use Markdown.

            You have access to the rooms table, which provides information about
            the hotel with the following columns:
             - room_id: Primary key for the table
             - room_number: The room number
             - floor: The floor the room is on
             - type: An SQL enum describing the type of room.
               Options are {self.room_type_enum}
             - square_feet: The size of the room in square feet
             - basic_amenities: Array of the basic amenities found in the room,
               chosen from the SQL list {self.basic_amenities}
             - additional_amenities: Array of additional amenities found in the room,
               chosen from the SQL list {self.additional_amenities}.
             - max_occupancy: The maximum number of people allowed to stay in the room
             - bed_type: An SQL enum describing the type of bed(s).
               Options are {self.room_bed_type_enum}.
             - view_type: Array of the views provided by the room,
               chosen from the SQL list {self.view_types}
             - accessibility: A boolean specifying whether the room is
               handicapped accessible
             - status: Ignore this
             - last_renovation: When the room was last renovated
             - base_rate: The base price a night in the room can be booked for
             - max_rate: The maximum price charge to book the room for the night

            You have access to the table room_availability, which provides information
            on the availability of rooms in a hotel, with the following columns:
             - room_id: Foreign key referring to the room_id in the rooms table
             - room_number: The room number
             - date: The date the availability information in this row is for
             - status: Whether the room is available or not.
               Options are Available, Booked, and Maintenance.
             - price: The current price to book the room for that date
             - max_occupancy: The maximum number of people who can stay in the room
        """

        return self.llm.responses.create(
            model="gpt-5.6-luna",
            instructions=instructions,
            input=query,
        )

neon_conn = psycopg.connect(neon_conn_string)
openai_conn = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
nl_2_sql_agent = NL2SQLAgent(neon_conn, openai_conn)

# %%
def parse_to_sql(nl_query: str) -> Response:
    """Translate a natural-language query into SQL via the NL2SQL agent.

    Args:
        nl_query: The user's natural-language question about hotel rooms
            or their availability.

    Returns:
        The OpenAI response object whose `output_text` holds the generated
        SQL query.

    """
    return nl_2_sql_agent.handle_nl_query(nl_query)

# %% [markdown]
# #### Test 1

# %%
query = 'Show me rooms with a view of the ocean and a 55" TV'
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT
#     room_id,
#     room_number,
#     floor,
#     type,
#     square_feet,
#     basic_amenities,
#     additional_amenities,
#     max_occupancy,
#     bed_type,
#     view_type,
#     accessibility,
#     last_renovation,
#     base_rate,
#     max_rate
# FROM rooms
# WHERE ('Ocean View' = ANY(view_type) OR 'Panoramic Ocean View' = ANY(view_type))
#   AND '55" Smart TV' = ANY(basic_amenities);

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'floor', type: int4 (oid: 23)>, <Column 'type', type: 147457 (oid: 147457)>, <Column 'square_feet', type: int4 (oid: 23)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>, <Column 'max_occupancy', type: int4 (oid: 23)>, <Column 'bed_type', type: 147466 (oid: 147466)>, <Column 'view_type', type: text[] (oid: 1009)>, <Column 'accessibility', type: bool (oid: 16)>, <Column 'last_renovation', type: date (oid: 1082)>, <Column 'base_rate', type: numeric(10,2) (oid: 1700)>, <Column 'max_rate', type: numeric(10,2) (oid: 1700)>]
# [(122, 502, 5, 'Deluxe', 460, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Soaking Tub'], 3, 'Double Queen', ['Pool View', 'Ocean View'], False, datetime.date(2024, 11, 25), Decimal('500.00'), Decimal('750.00')), (123, 503, 5, 'Deluxe', 538, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Soaking Tub', 'Lounge Access', 'Balcony'], 3, 'Double Queen', ['Pool View', 'Ocean View'], False, datetime.date(2024, 10, 2), Decimal('500.00'), Decimal('750.00')), (124, 504, 5, 'Deluxe', 565, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Lounge Access', 'Balcony'], 3, 'Double Queen', ['Ocean View'], False, datetime.date(2023, 1, 20), Decimal('500.00'), Decimal('750.00')), (125, 505, 5, 'Deluxe', 456, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Soaking Tub'], 3, 'Double Queen', ['Pool View', 'Ocean View'], False, datetime.date(2023, 5, 16), Decimal('500.00'), Decimal('750.00')), (127, 507, 5, 'Deluxe', 459, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Lounge Access'], 3, 'Double Queen', ['Ocean View'], False, datetime.date(2023, 10, 22), Decimal('500.00'), Decimal('750.00')), (129, 509, 5, 'Deluxe', 469, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Lounge Access'], 3, 'King', ['Ocean View'], False, datetime.date(2024, 9, 16), Decimal('500.00'), Decimal('750.00')), (130, 510, 5, 'Deluxe', 492, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Soaking Tub'], 3, 'King', ['Ocean View'], False, datetime.date(2022, 9, 30), Decimal('500.00'), Decimal('750.00')), (131, 511, 5, 'Deluxe', 461, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Soaking Tub', 'Lounge Access'], 3, 'Double Queen', ['Pool View', 'Ocean View'], False, datetime.date(2023, 5, 10), Decimal('500.00'), Decimal('750.00')), (133, 513, 5, 'Deluxe', 450, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Soaking Tub', 'Lounge Access', 'Balcony'], 3, 'King', ['Pool View', 'Ocean View'], False, datetime.date(2022, 6, 4), Decimal('500.00'), Decimal('750.00')), (135, 515, 5, 'Deluxe', 466, ['Air Conditioning', '55" Smart TV', 'Nespresso Machine', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bluetooth Speaker', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Evening Turndown Service'], ['Lounge Access', 'Balcony'], 3, 'King', [' ...

# %% [markdown]
# #### Test 2

# %%
query = "I'd like a room for May 20, 2025 for less than $500 with a view of the city."
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT r.*, ra.price AS nightly_price
# FROM rooms AS r
# JOIN room_availability AS ra
#   ON ra.room_id = r.room_id
# WHERE ra.date = DATE '2025-05-20'
#   AND ra.status = 'Available'
#   AND ra.price < 500
#   AND 'City View' = ANY(r.view_type);

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'floor', type: int4 (oid: 23)>, <Column 'type', type: 147457 (oid: 147457)>, <Column 'square_feet', type: int4 (oid: 23)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>, <Column 'max_occupancy', type: int4 (oid: 23)>, <Column 'bed_type', type: 147466 (oid: 147466)>, <Column 'view_type', type: text[] (oid: 1009)>, <Column 'accessibility', type: bool (oid: 16)>, <Column 'status', type: 147480 (oid: 147480)>, <Column 'last_renovation', type: date (oid: 1082)>, <Column 'base_rate', type: numeric(10,2) (oid: 1700)>, <Column 'max_rate', type: numeric(10,2) (oid: 1700)>, <Column 'nightly_price', type: numeric(8,2) (oid: 1700)>]
# [(1, 101, 1, 'Standard', 410, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], [], 2, 'Queen', ['City View'], False, 'Available', datetime.date(2022, 10, 25), Decimal('350.00'), Decimal('500.00'), Decimal('341.30')), (10, 110, 1, 'Standard', 359, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service'], 2, 'Double Queen', ['City View'], False, 'Maintenance', datetime.date(2023, 6, 26), Decimal('350.00'), Decimal('500.00'), Decimal('363.41')), (12, 112, 1, 'Standard', 430, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service'], 2, 'Queen', ['City View', 'Courtyard View'], False, 'Occupied', datetime.date(2024, 2, 24), Decimal('350.00'), Decimal('500.00'), Decimal('326.17')), (16, 116, 1, 'Standard', 396, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service'], 2, 'Queen', ['City View', 'Courtyard View'], False, 'Maintenance', datetime.date(2022, 8, 24), Decimal('350.00'), Decimal('500.00'), Decimal('360.64')), (20, 120, 1, 'Standard', 390, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service'], 2, 'Queen', ['City View', 'Courtyard View'], False, 'Occupied', datetime.date(2022, 2, 26), Decimal('350.00'), Decimal('500.00'), Decimal('376.97')), (23, 123, 1, 'Standard', 395, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service'], 2, 'Queen', ['City View'], False, 'Maintenance', datetime.date(2022, 3, 17), Decimal('350.00'), Decimal('500.00'), Decimal('342.77')), (25, 125, 1, 'Standard', 430, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service'], 2, 'Queen', ['City View', 'Courtyard View'], True, 'Occupied', datetime.date(2023, 9, 12), Decimal('350.00'), Decimal('500.00'), Decimal('342.22')), (28, 128, 1, 'Standard', 449, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], [], 2, 'Queen', ['City View', 'Courtyard View'], False, 'Available', datetime.date(2022, 10, 2), Decimal('350.00'), Decimal('500.00'), Decimal('367.58')), (29, 129, 1, 'Standard', 447, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service'], 2, 'Double Queen', ['City View', 'Courtyard View'], False, 'Maintenance', datetime.date(2023, 9, 23), Decimal('350.00'), Decimal('500.00'), Decimal('352.15')), (32, 202, 2, 'Standard', 376, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service'], 2, 'Queen', ['City View', 'Courtyard View'], False, 'Maintenance', datetime.date(2023, 6, 15), Decimal('350.00'), Decimal('500.00'), Decimal('366.56')), (38, 208, 2, 'Standard', 391, ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], [], 2, 'Double Queen', ['City View', 'Courtyard View'], False, 'Maintenance', datetime.date(2023, 1, 10), Decimal('350.00'), Decimal('500.00'), Decimal('358.17')), (43, 213, 2, 'Standar ...

# %% [markdown]
# #### Test 3

# %%
query = (
    "Does the hotel have any rooms with a cold plunge pool and a view of the "
    "Eiffel Tower?"
)
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT room_id, room_number, type, basic_amenities, additional_amenities, view_type
# FROM rooms
# WHERE array_to_string(COALESCE(basic_amenities, ARRAY[]::text[]), ', ') ILIKE '%cold plunge%'
#   AND array_to_string(COALESCE(additional_amenities, ARRAY[]::text[]), ', ') ILIKE '%cold plunge%'
#   AND array_to_string(COALESCE(view_type, ARRAY[]::text[]), ', ') ILIKE '%Eiffel Tower%';

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'type', type: 147457 (oid: 147457)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>, <Column 'view_type', type: text[] (oid: 1009)>]
# []

# %% [markdown]
# #### Test 4

# %%
query = "Show me all the rooms that have sofa beds."
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT *
# FROM rooms
# WHERE bed_type IN ('King + Sofa Bed', 'King + Multiple Sofa Beds');

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'floor', type: int4 (oid: 23)>, <Column 'type', type: 147457 (oid: 147457)>, <Column 'square_feet', type: int4 (oid: 23)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>, <Column 'max_occupancy', type: int4 (oid: 23)>, <Column 'bed_type', type: 147466 (oid: 147466)>, <Column 'view_type', type: text[] (oid: 1009)>, <Column 'accessibility', type: bool (oid: 16)>, <Column 'status', type: 147480 (oid: 147480)>, <Column 'last_renovation', type: date (oid: 1082)>, <Column 'base_rate', type: numeric(10,2) (oid: 1700)>, <Column 'max_rate', type: numeric(10,2) (oid: 1700)>]
ndown Service', 'Welcome Amenity'], ['Wraparound Balcony'], 4, 'King + Sofa Bed', ['Standard View'], False, 'Available', datetime.date(2024, 8, 23), Decimal('1000.00'), Decimal('2000.00')), (348, 1218, 12, 'Suite', 1023, ['Air Conditioning', '65" Smart TV', 'Nespresso Machine', 'Full-Size Refrigerator', 'Hair Dryer', 'In-Room Safe', 'Executive Work Desk', 'Ultra-High-Speed WiFi', 'Bose Sound System', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Kitchenette', 'Dining Area', 'Living Room Area', 'Guest Bathroom', 'Evening Turndown Service', 'Welcome Amenity'], ['Jacuzzi Tub', 'Executive Lounge Access', 'Wine Fridge'], 4, 'King + Sofa Bed', ['Corner View', 'Ocean View'], False, 'Available', datetime.date(2022, 1, 17), Decimal('1000.00'), Decimal('2000.00')), (349, 1219, 12, 'Suite', 1014, ['Air Conditioning', '65" Smart TV', 'Nespresso Machine', 'Full-Size Refrigerator', 'Hair Dryer', 'In-Room Safe', 'Executive Work Desk', 'Ultra-High-Speed WiFi', 'Bose Sound System', 'Microwave', 'Premium Bathrobes', 'Designer Slippers', 'Kitchenette', 'Dining Area', 'Living Room Area', 'Guest Bathroom', 'Evening Turndown Service', 'Welcome Amenity'], ['Wraparound Balcony', 'Executi ...

# %% [markdown]
# #### Test 5
#
# Looks like putting together the natrual language response might require some care in this case (further handling instructions).

# %%
query = "Do any of the rooms provide chocolate on the pillow before bedtime?"
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT
#     room_id,
#     room_number,
#     type,
#     basic_amenities,
#     additional_amenities
# FROM rooms
# WHERE EXISTS (
#     SELECT 1
#     FROM unnest(basic_amenities || additional_amenities) AS amenity
#     WHERE amenity ILIKE '%chocolate%'
#        OR amenity ILIKE '%pillow%'
#        OR amenity ILIKE '%turndown%'
# );

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'type', type: 147457 (oid: 147457)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>]
# [(2, 102, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (4, 104, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (5, 105, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (6, 106, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (8, 108, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (10, 110, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (12, 112, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (15, 115, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (16, 116, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (17, 117, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (18, 118, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (19, 119, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (20, 120, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (21, 121, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (23, 123, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (24, 124, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (25, 125, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (29, 129, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', 'Slippers'], ['Evening Turndown Service']), (30, 130, 'Standard', ['Air Conditioning', 'Smart TV', 'Premium Coffee Maker', 'Mini Fridge', 'Hair Dryer', 'In-Room Safe', 'Work Desk', 'High-Speed WiFi', 'Bathrobes', ' ...
