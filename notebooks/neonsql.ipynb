# %% [markdown]
# ## Neon SQL
#
# I use Neon SQL (a cloud service) to store the rooms information. This notebook tests loading the data and retrieving it.

# %%
# ruff: noqa: T201, S101, S301

import os

import psycopg
from dotenv import load_dotenv
from psycopg import sql

# %%
# Load environment variables from .env file
load_dotenv()
neon_conn_string = os.environ["PGSQL_ROOT_PARENT_DB_URL"]

# %%
import pandas as pd

# %% [markdown]
# ## Rooms table
#
# First we need the rooms table as its primary key is referenced by the room_availability table.

# %%
df_rooms = pd.read_pickle("../data/pandas/rooms.pkl")
df_rooms
# Out:
#       room_id  room_number  floor                type  square_feet  \
# 0    RM000001          101      1            Standard          410
# 1    RM000002          102      1            Standard          361
# 2    RM000003          103      1            Standard          431
# 3    RM000004          104      1            Standard          391
# 4    RM000005          105      1            Standard          373
# ..        ...          ...    ...                 ...          ...
# 595  RM000596         2026     20  Presidential Suite         2369
# 596  RM000597         2027     20  Presidential Suite         2020
# 597  RM000598         2028     20  Presidential Suite         1883
# 598  RM000599         2029     20  Presidential Suite         1643
# 599  RM000600         2030     20  Presidential Suite         1671
#
#                                        basic_amenities  \
# 0    [Air Conditioning, Smart TV, Premium Coffee Ma...
# ...

# %%
print(df_rooms.iloc[121])
# Out:
# room_id                                                          RM000122
# room_number                                                           502
# floor                                                                   5
# type                                                               Deluxe
# square_feet                                                           460
# basic_amenities         [Air Conditioning, 55" Smart TV, Nespresso Mac...
# additional_amenities                                        [Soaking Tub]
# max_occupancy                                                           3
# bed_type                                                     Double Queen
# view_type                                         [Pool View, Ocean View]
# accessibility                                                       False
# status                                                           Occupied
# last_renovation                                                2024-11-25
# ...

# %% [markdown]
# Convert the room_id to an int for more efficient use in SQL.

# %%
df_rooms["room_id"] = df_rooms["room_id"].apply(lambda x: int(x[2:]))
df_rooms
# Out:
#      room_id  room_number  floor                type  square_feet  \
# 0          1          101      1            Standard          410
# 1          2          102      1            Standard          361
# 2          3          103      1            Standard          431
# 3          4          104      1            Standard          391
# 4          5          105      1            Standard          373
# ..       ...          ...    ...                 ...          ...
# 595      596         2026     20  Presidential Suite         2369
# 596      597         2027     20  Presidential Suite         2020
# 597      598         2028     20  Presidential Suite         1883
# 598      599         2029     20  Presidential Suite         1643
# 599      600         2030     20  Presidential Suite         1671
#
#                                        basic_amenities  \
# 0    [Air Conditioning, Smart TV, Premium Coffee Ma...
# 1    [Air Conditioning, Smart TV, Premium Coffee Ma...
# ...

# %% [markdown]
# Get room types to create enum

# %%
room_type = df_rooms["type"].unique().tolist()
room_type_str = "('" + "', '".join(room_type) + "')"
room_type_str
# Out:
# "('Standard', 'Deluxe', 'Suite', 'Presidential Suite')"

# %% [markdown]
# Get room bed types to create enum

# %%
room_bed_type = df_rooms["bed_type"].unique().tolist()
room_bed_type_str = "('" + "', '".join(room_bed_type) + "')"
room_bed_type_str
# Out:
# "('Queen', 'Double Queen', 'King', 'Double King', 'King + Sofa Bed', 'King + Multiple Sofa Beds')"

# %% [markdown]
# Get statuses to create enum

# %%
room_status_type = df_rooms["status"].unique().tolist()
room_status_type_str = "('" + "', '".join(room_status_type) + "')"
room_status_type_str
# Out:
# "('Available', 'Occupied', 'Maintenance')"

# %% [markdown]
# Check that room_ids are sequential and start with 1

# %%
assert sum(df_rooms["room_id"].iloc[1:].to_numpy() -
           df_rooms["room_id"].iloc[:-1].to_numpy()) == df_rooms.shape[0]-1
assert df_rooms["room_id"].iloc[0] == 1

# %% [markdown]
# For some reason only the room_type enum needs special treatment (otherwise there's a cache error). I use more complicated ones for the bed_type and status columns, but they don't have a problem.

# %%
from enum import Enum


class RoomType(Enum):
    """Room type stored in the SQL `room_type` enum column."""

    Standard = "Standard"
    Deluxe = "Deluxe"
    Suite = "Suite"
    Presidential_Suite = "Presidential Suite"

enum_room_type_mapping = {
    "Standard": RoomType.Standard,
    "Deluxe": RoomType.Deluxe,
    "Suite": RoomType.Suite,
    "Presidential Suite": RoomType.Presidential_Suite,
}

sql_room_type_mapping = [
        (RoomType.Standard, "Standard"),
        (RoomType.Deluxe, "Deluxe"),
        (RoomType.Suite, "Suite"),
        (RoomType.Presidential_Suite, "Presidential Suite"),
]

# %%
df_rooms["type"] = df_rooms["type"].apply(lambda x: enum_room_type_mapping[x])
df_rooms
# Out:
#      room_id  room_number  floor                         type  square_feet  \
# 0          1          101      1            RoomType.Standard          410
# 1          2          102      1            RoomType.Standard          361
# 2          3          103      1            RoomType.Standard          431
# 3          4          104      1            RoomType.Standard          391
# 4          5          105      1            RoomType.Standard          373
# ..       ...          ...    ...                          ...          ...
# 595      596         2026     20  RoomType.Presidential_Suite         2369
# 596      597         2027     20  RoomType.Presidential_Suite         2020
# 597      598         2028     20  RoomType.Presidential_Suite         1883
# 598      599         2029     20  RoomType.Presidential_Suite         1643
# 599      600         2030     20  RoomType.Presidential_Suite         1671
#
#                                        basic_amenities  \
# ...

# %% [markdown]
# Add table to Neon

# %%
from psycopg.types.enum import EnumInfo, register_enum

with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # drop existing stuff (if exists)
        cur.execute("DROP TABLE IF EXISTS rooms CASCADE;")
        cur.execute("DROP TYPE IF EXISTS room_type CASCADE;")
        cur.execute("DROP TYPE IF EXISTS room_bed_type CASCADE;")
        cur.execute("DROP TYPE IF EXISTS room_status_type CASCADE;")

        # Define enums for type, bed_type, and status
        cur.execute(
            sql.SQL("CREATE TYPE room_type AS ENUM ({values});").format(
                values=sql.SQL(", ").join(sql.Literal(v) for v in room_type),
            ),
        )
        cur.execute(
            sql.SQL("CREATE TYPE room_bed_type AS ENUM ({values});").format(
                values=sql.SQL(", ").join(sql.Literal(v) for v in room_bed_type),
            ),
        )
        cur.execute(
            sql.SQL("CREATE TYPE room_status_type AS ENUM ({values});").format(
                values=sql.SQL(", ").join(sql.Literal(v) for v in room_status_type),
            ),
        )

        # Create a new table
        cur.execute("""
            CREATE TABLE rooms (
                room_id INT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
                room_number INT NOT NULL,
                floor INT NOT NULL,
                type room_type,
                square_feet INT,
                basic_amenities TEXT[],  -- Array data type for basic amenities
                additional_amenities TEXT[], -- Array data type for additional amenities
                max_occupancy INT,
                bed_type room_bed_type,
                view_type TEXT[],  -- Array data type for view type
                accessibility BOOLEAN,
                status room_status_type,
                last_renovation DATE,
                base_rate NUMERIC(10, 2),
                max_rate NUMERIC(10, 2)
            );
        """)
        print("Finished creating table.")

    # room_type enum special treatment
    info = EnumInfo.fetch(neon_conn, "room_type")
    if info is None:
        msg = "room_type enum was not found in the database after creation."
        raise RuntimeError(msg)
    register_enum(info, context=neon_conn, enum=RoomType, mapping=sql_room_type_mapping)

    with neon_conn.cursor() as cur:
        # Insert room availability data
        cur.executemany(
            "INSERT INTO rooms VALUES (" + "%s, "*(len(df_rooms.columns)-1) + "%s);",
            df_rooms.to_numpy().tolist(),
        )
        print("Inserted data.")
# Out:
# Connection established
# Finished creating table.
# Inserted data.

# %% [markdown]
# ## Room Availability table
#
# Now add the room_availability table

# %%
df_room_availability = pd.read_pickle("../data/pandas/room_availability.pkl")
df_room_availability
# Out:
#         room_number       date   room_id     status    price  max_occupancy
# 0               101 2025-01-04  RM000001     Booked   492.84              2
# 1               101 2025-01-05  RM000001     Booked   492.84              2
# 2               101 2025-01-06  RM000001     Booked   264.31              2
# 3               101 2025-01-07  RM000001     Booked   371.27              2
# 4               101 2025-01-08  RM000001     Booked   310.95              2
# ...             ...        ...       ...        ...      ...            ...
# 218995         2030 2025-12-30  RM000600     Booked  7187.84              6
# 218996         2030 2025-12-31  RM000600     Booked  7187.84              6
# 218997         2030 2026-01-01  RM000600     Booked  7187.84              6
# 218998         2030 2026-01-02  RM000600  Available   4617.6              6
# 218999         2030 2026-01-03  RM000600  Available   5000.0              6
#
# [219000 rows x 6 columns]

# %% [markdown]
# Convert room_id to int for more efficient use in SQL and because used that way in rooms table.

# %%
df_room_availability["room_id"] = df_room_availability["room_id"].apply(
    lambda x: int(x[2:]),
)
df_room_availability
# Out:
#         room_number       date  room_id     status    price  max_occupancy
# 0               101 2025-01-04        1     Booked   492.84              2
# 1               101 2025-01-05        1     Booked   492.84              2
# 2               101 2025-01-06        1     Booked   264.31              2
# 3               101 2025-01-07        1     Booked   371.27              2
# 4               101 2025-01-08        1     Booked   310.95              2
# ...             ...        ...      ...        ...      ...            ...
# 218995         2030 2025-12-30      600     Booked  7187.84              6
# 218996         2030 2025-12-31      600     Booked  7187.84              6
# 218997         2030 2026-01-01      600     Booked  7187.84              6
# 218998         2030 2026-01-02      600  Available   4617.6              6
# 218999         2030 2026-01-03      600  Available   5000.0              6
#
# [219000 rows x 6 columns]

# %%
df_room_availability.to_numpy().tolist()
# Out:
# [[101, Timestamp('2025-01-04 00:00:00'), 1, 'Booked', 492.84, 2],
#  [101, Timestamp('2025-01-05 00:00:00'), 1, 'Booked', 492.84, 2],
#  [101, Timestamp('2025-01-06 00:00:00'), 1, 'Booked', 264.31, 2],
#  [101, Timestamp('2025-01-07 00:00:00'), 1, 'Booked', 371.27, 2],
#  [101, Timestamp('2025-01-08 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-09 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-10 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-11 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-12 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-13 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-14 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-15 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-16 00:00:00'), 1, 'Booked', 310.95, 2],
#  [101, Timestamp('2025-01-17 00:00:00'), 1, 'Booked', 310.95, 2],
# ...

# %% [markdown]
# Create the status enum string

# %%
availability_status_type = df_room_availability["status"].unique().tolist()
availability_status_type_str = "('" + "', '".join(availability_status_type) + "')"
availability_status_type_str
# Out:
# "('Booked', 'Available', 'Maintenance')"

# %% [markdown]
# This enum also has a problem with psycopg confusing it with the status enum for the rooms table.

# %%
from enum import Enum


class AvailabilityStatusType(Enum):
    """Status stored in the SQL `availability_status_type` enum column."""

    Booked = "Booked"
    Available = "Available"
    Maintenance = "Maintenance"

enum_availability_status_type_mapping = {
    "Booked": AvailabilityStatusType.Booked,
    "Available": AvailabilityStatusType.Available,
    "Maintenance": AvailabilityStatusType.Maintenance,
}

# %%
df_room_availability["status"] = df_room_availability["status"].apply(
    lambda x: enum_availability_status_type_mapping[x],
)
df_room_availability
# Out:
#         room_number       date  room_id                            status  \
# 0               101 2025-01-04        1     AvailabilityStatusType.Booked
# 1               101 2025-01-05        1     AvailabilityStatusType.Booked
# 2               101 2025-01-06        1     AvailabilityStatusType.Booked
# 3               101 2025-01-07        1     AvailabilityStatusType.Booked
# 4               101 2025-01-08        1     AvailabilityStatusType.Booked
# ...             ...        ...      ...                               ...
# 218995         2030 2025-12-30      600     AvailabilityStatusType.Booked
# 218996         2030 2025-12-31      600     AvailabilityStatusType.Booked
# 218997         2030 2026-01-01      600     AvailabilityStatusType.Booked
# 218998         2030 2026-01-02      600  AvailabilityStatusType.Available
# 218999         2030 2026-01-03      600  AvailabilityStatusType.Available
#
#           price  max_occupancy
# 0        492.84              2
# ...

# %%
df_room_availability.to_numpy()
# Out:
# array([[101, Timestamp('2025-01-04 00:00:00'), 1,
#         <AvailabilityStatusType.Booked: 'Booked'>, 492.84, 2],
#        [101, Timestamp('2025-01-05 00:00:00'), 1,
#         <AvailabilityStatusType.Booked: 'Booked'>, 492.84, 2],
#        [101, Timestamp('2025-01-06 00:00:00'), 1,
#         <AvailabilityStatusType.Booked: 'Booked'>, 264.31, 2],
#        ...,
#        [2030, Timestamp('2026-01-01 00:00:00'), 600,
#         <AvailabilityStatusType.Booked: 'Booked'>, 7187.84, 6],
#        [2030, Timestamp('2026-01-02 00:00:00'), 600,
#         <AvailabilityStatusType.Available: 'Available'>, 4617.6, 6],
#        [2030, Timestamp('2026-01-03 00:00:00'), 600,
#         <AvailabilityStatusType.Available: 'Available'>, 5000.0, 6]],
#       shape=(219000, 6), dtype=object)

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("DROP TABLE IF EXISTS room_availability;")
        cur.execute("DROP TYPE IF EXISTS availability_status_type CASCADE;")
        print("Finished dropping table and enum (if they existed).")

        cur.execute(
            sql.SQL("CREATE TYPE availability_status_type AS ENUM ({values});").format(
                values=sql.SQL(", ").join(
                    sql.Literal(v) for v in availability_status_type
                ),
            ),
        )
        # Create a new table
        cur.execute("""
            CREATE TABLE room_availability (
                id INT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
                room_id INT NOT NULL,
                room_number INT NOT NULL,
                date DATE NOT NULL,
                status availability_status_type,
                price NUMERIC(8,2),
                max_occupancy INT,
                FOREIGN KEY (room_id) REFERENCES rooms(room_id),
                CONSTRAINT room_availability_room_id_date_uniq UNIQUE (room_id, date)
            );
        """)
        print("Finished creating table.")

    # availability_status_type enum special treatment
    info = EnumInfo.fetch(neon_conn, "availability_status_type")
    if info is None:
        msg = "availability_status_type enum was not found in the database."
        raise RuntimeError(msg)
    register_enum(info, context=neon_conn, enum=AvailabilityStatusType)

    with neon_conn.cursor() as cur:
        # Insert room availability data
        cur.executemany(
            "INSERT INTO room_availability (room_number, date, room_id, status, "
            "price, max_occupancy) VALUES (%s, %s, %s, %s, %s, %s);",
            df_room_availability.to_numpy().tolist(),
        )
        print("Inserted data.")
# Out:
# Connection established
# Finished dropping table and enum (if they existed).
# Finished creating table.
# Inserted data.

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("SELECT COUNT(*) FROM room_availability")
        print(cur.fetchall())
# Out:
# Connection established
# [(219000,)]

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("""SELECT DISTINCT element FROM (
                SELECT unnest(basic_amenities) AS element
                FROM rooms
                UNION ALL
                SELECT unnest(additional_amenities) AS element
                FROM rooms);""")
        print(cur.fetchall())
# Out:
# Connection established
# ...

# %% [markdown]
# ## Customers Table

# %%
df_customers = pd.read_pickle("../data/pandas/customers.pkl")
df_customers
# Out:
#             first_name  last_name                              email  \
# customer_id
# 1               Robert      Smith       robert.smith@wyatt-huynh.com
# 2              Tiffany     Garner           tiffany.garner@smith.com
# 3             Jennifer     Miller      jennifer.miller@mccormick.com
# 4                Frank    Roberts           frank.roberts@davis.info
# 5             Patricia       Choi            patricia.choi@holt.info
# ...                ...        ...                                ...
# 49996            Stacy   Harrison            stacy.harrison@snow.com
# 49997           Cheryl   Santiago  cheryl.santiago@stone-jimenez.com
# 49998          Kaitlyn  Davenport  kaitlyn.davenport@hunt-austin.com
# 49999            Grant   Mcintosh          grant.mcintosh@howard.com
# 50000          Gregory      Duran   gregory.duran@anderson-smith.net
#
#                               phone  \
# customer_id
# 1                  001-625-164-8298
# ...

# %% [markdown]
# Insert customer data

# %%
df_customers = df_customers[["first_name", "last_name"]]
df_customers = df_customers.reset_index()

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("DROP TABLE IF EXISTS customers CASCADE;")
        print("Finished dropping table if it existed.")
        # Create a new table
        cur.execute("""
            CREATE TABLE customers (
                customer_id INT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
                first_name VARCHAR(32) NOT NULL,
                last_name VARCHAR(32) NOT NULL
            );
        """)
        print("Finished creating table.")

        # Insert customer data
        cur.executemany(
            "INSERT INTO customers (customer_id, first_name, last_name) "
            "VALUES (%s, %s, %s);",
            df_customers.to_numpy().tolist(),
        )
        print("Inserted data.")
# Out:
# Connection established
# Finished dropping table if it existed.
# Finished creating table.
# Inserted data.

# %% [markdown]
# ## Booking tables
#
# There are a bunch of pre-existing bookings; the cells below load them, after
# resolving overlaps and clamping to the dates `room_availability` covers. Cancelling
# one of these no longer leaves a room listed as "available" without a rate, since
# `room_availability`'s prices are already filled in for `Booked` rows (see
# `eda.ipynb`).
#
# I use two tables so that a single booking can cover multiple rooms. There's a
# `bookings` table with the corresponding guest id, then the `booking_rooms` table
# with a row for each room booked.

# %% [markdown]
# First the `bookings` table

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("DROP TABLE IF EXISTS bookings CASCADE;")
        cur.execute("DROP TYPE IF EXISTS booking_status CASCADE;")
        print("Finished dropping table if it existed.")
        # Create the enum
        cur.execute("""
            CREATE TYPE booking_status AS ENUM (
                'confirmed', 'checked_in', 'checked_out', 'cancelled'
                );
            """)
        # Create a new table
        cur.execute("""
            CREATE TABLE bookings (
                booking_id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
                customer_id INT NOT NULL
                    REFERENCES customers(customer_id) ON DELETE RESTRICT,
                status booking_status NOT NULL DEFAULT 'confirmed',
                booked_at TIMESTAMPTZ NOT NULL DEFAULT now(),
                cancelled_at TIMESTAMPTZ,
                confirmation_number VARCHAR(16) UNIQUE,
                CONSTRAINT cancel_coherent
                    CHECK ((status = 'cancelled') = (cancelled_at IS NOT NULL))
            );
        """)
        print("Finished creating table.")
# Out:
# Connection established
# Finished dropping table if it existed.
# Finished creating table.

# %% [markdown]
# Then the `booking_rooms` table, with the `booking_rooms_no_overlap` GiST exclusion constraint so that overlapping room bookings are impossible. The constraint needs the `btree_gist` extension for GiST to support `=` on the integer `room_id` column alongside the date-range overlap operator.

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    # Open a cursor to perform database operations
    with neon_conn.cursor() as cur:
        # Drop the table if it already exists
        cur.execute("DROP TABLE IF EXISTS booking_rooms;")
        print("Finished dropping table if it existed.")
        cur.execute("CREATE EXTENSION IF NOT EXISTS btree_gist;")
        # Create a new table
        cur.execute("""
            CREATE TABLE booking_rooms (
                booking_room_id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
                booking_id BIGINT NOT NULL
                    REFERENCES bookings(booking_id) ON DELETE RESTRICT,
                room_id INT NOT NULL REFERENCES rooms(room_id),
                check_in DATE NOT NULL,
                check_out DATE NOT NULL,
                total_amount NUMERIC(10,2) NOT NULL,
                CHECK (check_out > check_in),
                CONSTRAINT booking_rooms_no_overlap EXCLUDE USING gist (
                    room_id WITH =,
                    daterange(check_in, check_out, '[)') WITH &&
                )
            );
        """)
        print("Finished creating table.")
# Out:
# Connection established
# Finished dropping table if it existed.
# Finished creating table.

# %% [markdown]
# Every `DROP TABLE ... CASCADE` above (`rooms`, `room_availability`, `customers`, `bookings`, `booking_rooms`) strips whatever grants were on that table. Reapply the `bh_agent_ro`/`bh_agent_rw` grants now by reading and executing `regrant_booking_agent_role.sql` rather than duplicating its logic. Note that `bh_agent_ro` and `bh_agent_rw` roles must exist in the database.

# %%
from pathlib import Path
from typing import LiteralString, cast

regrant_sql_path = Path("../blue_horizon/load_data/regrant_booking_agent_role.sql")
# SQL() requires a LiteralString because it does no escaping -- a deliberate
# guard against composing untrusted/dynamic SQL text. This is a repo-committed
# script read verbatim, not untrusted input, so the cast documents that this is
# exactly the case the guard is fine with (mirrors regrant_booking_agent_role()
# in booking_pgsql.py).
regrant_sql_text = cast(
    "LiteralString", regrant_sql_path.read_text(encoding="utf-8"),
)

with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    neon_conn.execute(sql.SQL(regrant_sql_text))
    print("Reapplied bh_agent_ro/bh_agent_rw grants.")
# Out:
# Connection established
# Reapplied bh_agent_ro/bh_agent_rw grants.

# %% [markdown]
# Now upload the existing booking data to the booking tables

# %%
df_bookings = pd.read_pickle("../data/pandas/room_bookings.pkl")
# The pickle's index holds source ids like "BK000001". Keep it under its own
# name -- `bookings.booking_id` below is a different, DB-generated integer.
df_bookings = df_bookings.reset_index(names="source_booking_id")
df_bookings
# Out:
#       source_booking_id  customer_id  room_number           room_type  \
# 0              BK000001        20963         1730               Suite
# 1              BK000002        11750          928              Deluxe
# 2              BK000003         2178          525              Deluxe
# 3              BK000004        19877          113            Standard
# 4              BK000005        44458         1002              Deluxe
# ...                 ...          ...          ...                 ...
# 49995          BK049996        22089         2019  Presidential Suite
# 49996          BK049997        35986          614              Deluxe
# 49997          BK049998         2468          830              Deluxe
# 49998          BK049999         5728          206            Standard
# 49999          BK050000        41970         1316               Suite
#
#         check_in  check_out  duration_days  num_adults  num_children  \
# ...

# %% [markdown]
# Map `room_number` to the `room_id` primary key `rooms` uses, via the `df_rooms` frame loaded above.

# %%
room_id_by_number = dict(
    zip(df_rooms["room_number"], df_rooms["room_id"], strict=True),
)
df_bookings["room_id"] = df_bookings["room_number"].map(room_id_by_number)
assert df_bookings["room_id"].notna().all()
df_bookings["room_id"] = df_bookings["room_id"].astype(int)
df_bookings[["source_booking_id", "room_number", "room_id"]]
# Out:
#       source_booking_id  room_number  room_id
# 0              BK000001         1730      510
# 1              BK000002          928      268
# 2              BK000003          525      145
# 3              BK000004          113       13
# 4              BK000005         1002      272
# ...                 ...          ...      ...
# 49995          BK049996         2019      589
# 49996          BK049997          614      164
# 49997          BK049998          830      240
# 49998          BK049999          206       36
# 49999          BK050000         1316      376
#
# [50000 rows x 3 columns]

# %% [markdown]
# `room_availability` only covers the dates present in `df_room_availability["date"]`
# (loaded above), up to one day past its last date (`check_out` is exclusive). Some
# source bookings fall partly or entirely outside that window.
#
# Bookings that fall entirely outside the window (`check_out` at or before the
# earliest covered date, or `check_in` at or after one day past the latest covered
# date) are dropped rather than clamped -- clamping only one end of those would
# produce a zero- or negative-length stay, which `booking_rooms`'s
# `CHECK (check_out > check_in)` refuses. For every remaining booking, `check_in` is
# raised to the earliest covered date if it's earlier, and `check_out` is lowered to
# one day past the latest covered date if it's later.

# %%
room_availability_dates = pd.to_datetime(df_room_availability["date"])
room_availability_min_date = room_availability_dates.min()
room_availability_max_date = room_availability_dates.max() + pd.Timedelta(days=1)

out_of_range = (df_bookings["check_out"] <= room_availability_min_date) | (
    df_bookings["check_in"] >= room_availability_max_date
)
dropped_out_of_range_ids = df_bookings.loc[out_of_range, "source_booking_id"]
df_bookings = df_bookings.loc[~out_of_range].copy()

df_bookings["check_in"] = df_bookings["check_in"].clip(
    lower=room_availability_min_date,
)
df_bookings["check_out"] = df_bookings["check_out"].clip(
    upper=room_availability_max_date,
)

print(
    f"Dropped {len(dropped_out_of_range_ids)} bookings entirely outside "
    f"room_availability's covered range [{room_availability_min_date.date()}, "
    f"{room_availability_max_date.date()}); clamped check_in/check_out on the "
    f"remaining {len(df_bookings)} rows to that range.",
)
# Out:
# Dropped 24407 bookings entirely outside room_availability's covered range [2025-01-04, 2026-01-04); clamped check_in/check_out on the remaining 25593 rows to that range.

# %% [markdown]
# Every row is loaded as a `confirmed` booking regardless of the source `booking_status`
# (including rows the source data marked `Cancelled`), because the pre-generated
# `room_availability` table already marks those rooms/dates as `Booked` on account of
# these reservations.
#
# `booking_rooms` carries the `booking_rooms_no_overlap` GiST exclusion constraint (see
# `booking_pgsql.py`), which refuses two rows for the same room with overlapping
# `[check_in, check_out)` spans, and this source data does have such overlaps for a
# given room. Before inserting anything, sort each room's rows by `check_out` and
# greedily keep a row whenever its `check_in` is on or after the last *kept* row's
# `check_out`. This is the classic interval-scheduling greedy: sorting by `check_out`
# (rather than `check_in`, or leaving rows in source order) maximizes the number of
# rows kept, and once sorted, comparing only against the most recently kept row per
# room is enough to catch any overlap -- an O(n log n) sort plus a single O(n) pass,
# no network round trip needed to find out what the live constraint would decide.

# %%
def select_non_overlapping(df: pd.DataFrame) -> pd.Series:
    """Keep the maximum non-overlapping subset of bookings, per room.

    Sorts each room's rows by ``check_out`` and greedily keeps a row whenever
    its ``check_in`` is on or after the ``check_out`` of the last row kept for
    that room. Once sorted, kept intervals for a room are automatically
    ordered by both ``check_in`` and ``check_out``, so comparing only against
    the most recently kept row (rather than every row kept so far) is enough
    to catch any overlap. Sorting by ``check_out`` is the classic
    interval-scheduling greedy: it maximizes the number of rows kept, which
    sorting by ``check_in`` -- or leaving rows in source order -- does not
    guarantee.

    Args:
        df: Bookings with ``room_id``, ``check_in``, and ``check_out``
            columns.

    Returns:
        pd.Series: Boolean mask aligned to `df`'s index, True for rows to
        keep.

    """
    sorted_df = df.sort_values(["room_id", "check_out"])
    last_check_out: dict[int, pd.Timestamp] = {}
    keep = []
    for room_id, check_in, check_out in zip(
        sorted_df["room_id"], sorted_df["check_in"], sorted_df["check_out"],
        strict=True,
    ):
        room_last_check_out = last_check_out.get(room_id)
        kept = room_last_check_out is None or check_in >= room_last_check_out
        keep.append(kept)
        if kept:
            last_check_out[room_id] = check_out
    return pd.Series(keep, index=sorted_df.index).reindex(df.index)


df_bookings["accepted"] = select_non_overlapping(df_bookings)
skipped_booking_ids = df_bookings.loc[~df_bookings["accepted"], "source_booking_id"]
print(
    f"{df_bookings['accepted'].sum()} of {len(df_bookings)} bookings kept; "
    f"{len(skipped_booking_ids)} skipped for overlapping an already-kept "
    "booking on the same room.",
)
skipped_booking_ids
# Out:
# 14617 of 25593 bookings kept; 10976 skipped for overlapping an already-kept booking on the same room.
# 1        BK000002
# 7        BK000008
# 8        BK000009
# 9        BK000010
# 12       BK000013
#            ...
# 49983    BK049984
# 49993    BK049994
# 49994    BK049995
# 49995    BK049996
# 49997    BK049998
# Name: source_booking_id, Length: 10976, dtype: str

# %% [markdown]
# Insert the kept bookings using the same `cur.executemany` pattern the earlier tables
# use, just with `returning=True` so each statement's generated `booking_id` can be
# read back in submission order via `fetchone()`/`nextset()`. `executemany` runs one
# single-row statement per booking, each with a fixed, small number of bound
# parameters, so -- like the 219,000-row `room_availability` load above -- the number
# of bookings never interacts with Postgres's per-statement bind-parameter limit.
# Each booking's `confirmation_number` is then set to match the `BH######` format
# `write_ops._confirmation_number` uses for bookings made through the app. Finally
# `booking_rooms` is inserted for every kept row; since overlaps were already filtered
# out above, `booking_rooms_no_overlap` should not reject anything here.

# %%
df_accepted = df_bookings.loc[df_bookings["accepted"]].reset_index(drop=True)

with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    with neon_conn.cursor() as cur:
        cur.executemany(
            "INSERT INTO bookings (customer_id, status) "
            "VALUES (%s, 'confirmed') RETURNING booking_id;",
            [(customer_id,) for customer_id in df_accepted["customer_id"]],
            returning=True,
        )
        # Each statement returns exactly one row; cur.results() walks the
        # per-statement result sets executemany(returning=True) produced, in
        # submission order.
        booking_ids = []
        for result in cur.results():
            row = result.fetchone()
            assert row is not None
            booking_ids.append(row[0])
        assert len(booking_ids) == len(df_accepted)
        df_accepted["booking_id"] = booking_ids
        print("Inserted bookings.")

        cur.execute("""
            UPDATE bookings
            SET confirmation_number = 'BH' || lpad(booking_id::text, 6, '0')
            WHERE confirmation_number IS NULL;
        """)
        print("Set confirmation numbers.")

        df_booking_rooms = df_accepted[
            ["booking_id", "room_id", "check_in", "check_out", "total_amount"]
        ].copy()
        df_booking_rooms["check_in"] = df_booking_rooms["check_in"].dt.date
        df_booking_rooms["check_out"] = df_booking_rooms["check_out"].dt.date

        cur.executemany(
            "INSERT INTO booking_rooms "
            "(booking_id, room_id, check_in, check_out, total_amount) "
            "VALUES (%s, %s, %s, %s, %s);",
            df_booking_rooms.itertuples(index=False, name=None),
        )
        print("Inserted booking_rooms.")

print(
    f"Loaded {len(df_accepted)} of {len(df_bookings)} pre-existing bookings "
    f"({len(skipped_booking_ids)} skipped for overlapping another kept "
    "booking on the same room).",
)
# Out:
# Connection established
# Inserted bookings.
# Set confirmation numbers.
# Inserted booking_rooms.
# Loaded 14617 of 25593 pre-existing bookings (10976 skipped for overlapping another kept booking on the same room).

# %%
with psycopg.connect(neon_conn_string) as neon_conn, neon_conn.cursor() as cur:
    cur.execute("SELECT COUNT(*) FROM bookings;")
    print("bookings:", cur.fetchall())
    cur.execute("SELECT COUNT(*) FROM booking_rooms;")
    print("booking_rooms:", cur.fetchall())
# Out:
# bookings: [(14617,)]
# booking_rooms: [(14617,)]

# %% [markdown]
# Reconcile `room_availability` against what actually made it into `booking_rooms`,
# in both directions.
#
# The overlap filter above skipped a large share of the source bookings, so plenty of
# rows the pre-generated `room_availability` table marked `Booked` no longer have a
# matching reservation. For every such row, set `status = 'Available'`.
#
# Note: `price` is already filled in for `Booked` rows in the seed data (see
# `eda.ipynb`, which backfills it from the overlapping reservations' `total_amount`),
# so this flip carries a real price forward rather than leaving it `NULL` -- only
# `Maintenance` rows, which this step never touches, are still `NULL`.
#
# The reverse direction is checked too: any `Available` row that does have a matching
# `booking_rooms` reservation is set back to `Booked`. `price` is left untouched here,
# matching how the live app actually books a room (`write_ops.commit_booking` only
# ever flips `status`, per its module docstring, so the nightly rate survives a
# book-then-cancel round trip) -- and, now that `room_availability`'s prices are
# filled in for `Booked` rows generally, that's consistent with every other `Booked`
# row rather than an exception to it.

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    with neon_conn.cursor() as cur:
        cur.execute("""
            SELECT COUNT(*)
            FROM room_availability AS ra
            WHERE ra.status = 'Booked'
              AND NOT EXISTS (
                SELECT 1
                FROM booking_rooms AS br
                WHERE br.room_id = ra.room_id
                  AND ra.date >= br.check_in
                  AND ra.date < br.check_out
              );
        """)
        row = cur.fetchone()
        assert row is not None
        unmatched_booked_count = row[0]
        print(
            f"{unmatched_booked_count} room_availability rows are Booked with no "
            "matching booking_rooms reservation.",
        )

        cur.execute("""
            UPDATE room_availability AS ra
            SET status = 'Available'
            WHERE ra.status = 'Booked'
              AND NOT EXISTS (
                SELECT 1
                FROM booking_rooms AS br
                WHERE br.room_id = ra.room_id
                  AND ra.date >= br.check_in
                  AND ra.date < br.check_out
              );
        """)
        print(f"Updated {cur.rowcount} rows to Available.")

        cur.execute("""
            SELECT COUNT(*)
            FROM room_availability AS ra
            WHERE ra.status = 'Available'
              AND EXISTS (
                SELECT 1
                FROM booking_rooms AS br
                WHERE br.room_id = ra.room_id
                  AND ra.date >= br.check_in
                  AND ra.date < br.check_out
              );
        """)
        row = cur.fetchone()
        assert row is not None
        unmatched_available_count = row[0]
        print(
            f"{unmatched_available_count} room_availability rows are Available "
            "despite having a matching booking_rooms reservation.",
        )

        cur.execute("""
            UPDATE room_availability AS ra
            SET status = 'Booked'
            WHERE ra.status = 'Available'
              AND EXISTS (
                SELECT 1
                FROM booking_rooms AS br
                WHERE br.room_id = ra.room_id
                  AND ra.date >= br.check_in
                  AND ra.date < br.check_out
              );
        """)
        print(f"Updated {cur.rowcount} rows to Booked.")
# Out:
# Connection established
# 39290 room_availability rows are Booked with no matching booking_rooms reservation.
# Updated 39290 rows to Available.
# 0 room_availability rows are Available despite having a matching booking_rooms reservation.
# Updated 0 rows to Booked.

# %%
with psycopg.connect(neon_conn_string) as neon_conn, neon_conn.cursor() as cur:
    cur.execute("SELECT status, COUNT(*) FROM room_availability GROUP BY status;")
    print(cur.fetchall())
# Out:
# [('Booked', 90640), ('Available', 126667), ('Maintenance', 1693)]

# %% [markdown]
# ## Prevent booking a room under maintenance
#
# Add a trigger on `booking_rooms` that refuses to insert (or update) a row covering
# any night where `room_availability.status = 'Maintenance'` for that room. This is a
# database-level backstop, the same spirit as `booking_rooms_no_overlap` above: it
# catches the case regardless of which code path writes to `booking_rooms`, rather
# than relying on every caller to check first. `RAISE EXCEPTION ... USING ERRCODE`
# reuses `check_violation` (SQLSTATE `23514`) so the failure looks like an ordinary
# check-constraint violation to anything catching `psycopg.errors.CheckViolation`.

# %%
with psycopg.connect(neon_conn_string) as neon_conn:
    print("Connection established")
    with neon_conn.cursor() as cur:
        cur.execute(
            "DROP TRIGGER IF EXISTS booking_rooms_no_maintenance ON booking_rooms;",
        )
        cur.execute("DROP FUNCTION IF EXISTS prevent_maintenance_booking();")

        cur.execute("""
            CREATE FUNCTION prevent_maintenance_booking()
            RETURNS TRIGGER AS $$
            BEGIN
                IF EXISTS (
                    SELECT 1
                    FROM room_availability
                    WHERE room_id = NEW.room_id
                      AND date >= NEW.check_in
                      AND date < NEW.check_out
                      AND status = 'Maintenance'
                ) THEN
                    RAISE EXCEPTION
                        'Room % is under maintenance for one or more nights in [%, %)',
                        NEW.room_id, NEW.check_in, NEW.check_out
                        USING ERRCODE = 'check_violation';
                END IF;
                RETURN NEW;
            END;
            $$ LANGUAGE plpgsql;
        """)
        print("Created prevent_maintenance_booking().")

        cur.execute("""
            CREATE TRIGGER booking_rooms_no_maintenance
            BEFORE INSERT OR UPDATE ON booking_rooms
            FOR EACH ROW
            EXECUTE FUNCTION prevent_maintenance_booking();
        """)
        print("Created booking_rooms_no_maintenance trigger.")
# Out:
# Connection established
# Created prevent_maintenance_booking().
# Created booking_rooms_no_maintenance trigger.

# %% [markdown]
# ### Run Some Tests

# %%
from openai import OpenAI
from openai.types.responses import Response


class NL2SQLAgent:
    """Agent that translates natural-language questions into SQL queries.

    Uses an LLM to draft a PostgreSQL query for the `rooms` and
    `room_availability` tables, given the enums, amenities, and view types
    currently stored in the database.
    """

    def __init__(self, db_conn: psycopg.Connection, llm_conn: OpenAI) -> None:
        """Initialize the agent and cache the schema metadata it needs.

        Args:
            db_conn: Open connection to the Neon PostgreSQL database.
            llm_conn: OpenAI client used to generate SQL from natural language.

        """
        self.db = db_conn
        self.llm = llm_conn
        self._get_enums()
        self._get_amenities()
        self._get_view_types()

    def _get_enums(self) -> None:
        """Fetch and cache the SQL enum ranges used by the rooms tables."""
        with psycopg.connect(neon_conn_string) as neon_conn, neon_conn.cursor() as cur:
            cur.execute("SELECT enum_range(NULL::room_type);")
            self.room_type_enum = cur.fetchall()[0][0]
            cur.execute("SELECT enum_range(NULL::room_bed_type);")
            self.room_bed_type_enum = cur.fetchall()[0][0]
            cur.execute("SELECT enum_range(NULL::room_status_type);")
            self.room_status_type_enum = cur.fetchall()[0][0]
            cur.execute("SELECT enum_range(NULL::availability_status_type);")
            self.availability_status_type_enum = cur.fetchall()[0][0]

    def _get_amenities(self) -> None:
        """Fetch and cache the distinct basic and additional room amenities."""
        with psycopg.connect(neon_conn_string) as neon_conn, neon_conn.cursor() as cur:
            cur.execute("SELECT DISTINCT unnest(basic_amenities) FROM rooms;")
            self.basic_amenities = cur.fetchall()
            cur.execute("SELECT DISTINCT unnest(additional_amenities) FROM rooms;")
            self.additional_amenities = cur.fetchall()

    def _get_view_types(self) -> None:
        """Fetch and cache the distinct room view types."""
        with psycopg.connect(neon_conn_string) as neon_conn, neon_conn.cursor() as cur:
            cur.execute("SELECT DISTINCT unnest(view_type) FROM rooms;")
            self.view_types = cur.fetchall()

    def handle_nl_query(self, query: str) -> Response:
        """Translate a natural-language question into a SQL query.

        Args:
            query: The user's natural-language question about hotel rooms
                or their availability.

        Returns:
            The OpenAI response whose `output_text` holds the generated
            SQL query.

        """
        instructions = f"""
            You are a SQL query writer. Given the user's input, write a query that, when
            passed to a PostgreSQL database, will gather the data necessary to answer
            the user's query. Write a raw query. Do not use Markdown.

            You have access to the rooms table, which provides information about
            the hotel with the following columns:
             - room_id: Primary key for the table
             - room_number: The room number
             - floor: The floor the room is on
             - type: An SQL enum describing the type of room.
               Options are {self.room_type_enum}
             - square_feet: The size of the room in square feet
             - basic_amenities: Array of the basic amenities found in the room,
               chosen from the SQL list {self.basic_amenities}
             - additional_amenities: Array of additional amenities found in the room,
               chosen from the SQL list {self.additional_amenities}.
             - max_occupancy: The maximum number of people allowed to stay in the room
             - bed_type: An SQL enum describing the type of bed(s).
               Options are {self.room_bed_type_enum}.
             - view_type: Array of the views provided by the room,
               chosen from the SQL list {self.view_types}
             - accessibility: A boolean specifying whether the room is
               handicapped accessible
             - status: Ignore this
             - last_renovation: When the room was last renovated
             - base_rate: The base price a night in the room can be booked for
             - max_rate: The maximum price charge to book the room for the night

            You have access to the table room_availability, which provides information
            on the availability of rooms in a hotel, with the following columns:
             - room_id: Foreign key referring to the room_id in the rooms table
             - room_number: The room number
             - date: The date the availability information in this row is for
             - status: Whether the room is available or not.
               Options are Available, Booked, and Maintenance.
             - price: The current price to book the room for that date
             - max_occupancy: The maximum number of people who can stay in the room
        """

        return self.llm.responses.create(
            model="gpt-5.6-luna",
            instructions=instructions,
            input=query,
        )

neon_conn = psycopg.connect(neon_conn_string)
openai_conn = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
nl_2_sql_agent = NL2SQLAgent(neon_conn, openai_conn)

# %%
def parse_to_sql(nl_query: str) -> Response:
    """Translate a natural-language query into SQL via the NL2SQL agent.

    Args:
        nl_query: The user's natural-language question about hotel rooms
            or their availability.

    Returns:
        The OpenAI response object whose `output_text` holds the generated
        SQL query.

    """
    return nl_2_sql_agent.handle_nl_query(nl_query)

# %% [markdown]
# #### Test 1

# %%
query = 'Show me rooms with a view of the ocean and a 55" TV'
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT *
# FROM rooms
# WHERE basic_amenities @> ARRAY['55" Smart TV']
#   AND view_type && ARRAY['Ocean View', 'Panoramic Ocean View'];

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'floor', type: int4 (oid: 23)>, <Column 'type', type: 172033 (oid: 172033)>, <Column 'square_feet', type: int4 (oid: 23)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>, <Column 'max_occupancy', type: int4 (oid: 23)>, <Column 'bed_type', type: 172042 (oid: 172042)>, <Column 'view_type', type: text[] (oid: 1009)>, <Column 'accessibility', type: bool (oid: 16)>, <Column 'status', type: 172056 (oid: 172056)>, <Column 'last_renovation', type: date (oid: 1082)>, <Column 'base_rate', type: numeric(10,2) (oid: 1700)>, <Column 'max_rate', type: numeric(10,2) (oid: 1700)>]
# ...

# %% [markdown]
# #### Test 2

# %%
query = "I'd like a room for May 20, 2025 for less than $500 with a view of the city."
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT
#     r.room_id,
#     r.room_number,
#     r.floor,
#     r.type,
#     r.square_feet,
#     r.basic_amenities,
#     r.additional_amenities,
#     r.max_occupancy,
#     r.bed_type,
#     r.view_type,
#     r.accessibility,
#     r.last_renovation,
#     r.base_rate,
#     r.max_rate,
#     ra.date,
#     ra.status,
#     ra.price
# FROM rooms AS r
# JOIN room_availability AS ra
#     ON ra.room_id = r.room_id
# WHERE ra.date = DATE '2025-05-20'
#   AND ra.status = 'Available'
#   AND ra.price < 500
#   AND 'City View' = ANY (r.view_type)
# ORDER BY ra.price ASC, r.room_number;

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'floor', type: int4 (oid: 23)>, <Column 'type', type: 172033 (oid: 172033)>, <Column 'square_feet', type: int4 (oid: 23)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>, <Column 'max_occupancy', type: int4 (oid: 23)>, <Column 'bed_type', type: 172042 (oid: 172042)>, <Column 'view_type', type: text[] (oid: 1009)>, <Column 'accessibility', type: bool (oid: 16)>, <Column 'last_renovation', type: date (oid: 1082)>, <Column 'base_rate', type: numeric(10,2) (oid: 1700)>, <Column 'max_rate', type: numeric(10,2) (oid: 1700)>, <Column 'date', type: date (oid: 1082)>, <Column 'status', type: 172115 (oid: 172115)>, <Column 'price', type: numeric(8,2) (oid: 1700)>]
# ...

# %% [markdown]
# #### Test 3

# %%
query = (
    "Does the hotel have any rooms with a cold plunge pool and a view of the "
    "Eiffel Tower?"
)
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT
#     room_id,
#     room_number,
#     type,
#     basic_amenities,
#     additional_amenities,
#     view_type
# FROM rooms
# WHERE EXISTS (
#     SELECT 1
#     FROM unnest(COALESCE(basic_amenities, ARRAY[]::text[]) || COALESCE(additional_amenities, ARRAY[]::text[])) AS amenity
#     WHERE LOWER(amenity) LIKE '%cold plunge%'
#        OR LOWER(amenity) LIKE '%plunge pool%'
# )
# AND EXISTS (
#     SELECT 1
#     FROM unnest(COALESCE(view_type, ARRAY[]::text[])) AS view
#     WHERE LOWER(view) LIKE '%eiffel tower%'
# );

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'type', type: 172033 (oid: 172033)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>, <Column 'view_type', type: text[] (oid: 1009)>]
# []

# %% [markdown]
# #### Test 4

# %%
query = "Show me all the rooms that have sofa beds."
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT *
# FROM rooms
# WHERE bed_type IN ('King + Sofa Bed', 'King + Multiple Sofa Beds');

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'floor', type: int4 (oid: 23)>, <Column 'type', type: 172033 (oid: 172033)>, <Column 'square_feet', type: int4 (oid: 23)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>, <Column 'max_occupancy', type: int4 (oid: 23)>, <Column 'bed_type', type: 172042 (oid: 172042)>, <Column 'view_type', type: text[] (oid: 1009)>, <Column 'accessibility', type: bool (oid: 16)>, <Column 'status', type: 172056 (oid: 172056)>, <Column 'last_renovation', type: date (oid: 1082)>, <Column 'base_rate', type: numeric(10,2) (oid: 1700)>, <Column 'max_rate', type: numeric(10,2) (oid: 1700)>]
# ...

# %% [markdown]
# #### Test 5
#
# Looks like putting together the natrual language response might require some care in this case (further handling instructions).

# %%
query = "Do any of the rooms provide chocolate on the pillow before bedtime?"
response_query = parse_to_sql(query)
print(response_query.output_text)
# Out:
# SELECT
#     room_id,
#     room_number,
#     type,
#     basic_amenities,
#     additional_amenities
# FROM rooms
# WHERE EXISTS (
#     SELECT 1
#     FROM unnest(basic_amenities || additional_amenities) AS amenity
#     WHERE amenity ILIKE '%chocolate%'
#        OR amenity ILIKE '%pillow%'
# );

# %%
query_result = neon_conn.execute(response_query.output_text.encode())
print(query_result.description)
print(query_result.fetchall())
# Out:
# [<Column 'room_id', type: int4 (oid: 23)>, <Column 'room_number', type: int4 (oid: 23)>, <Column 'type', type: 172033 (oid: 172033)>, <Column 'basic_amenities', type: text[] (oid: 1009)>, <Column 'additional_amenities', type: text[] (oid: 1009)>]
# []
